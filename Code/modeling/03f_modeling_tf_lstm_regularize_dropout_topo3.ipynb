# %% [markdown]
# # Modeling with Stemmed and Balanced Data

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

# standard sklearn imports
from sklearn.datasets import make_classification, make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# tensorflow imports for Neural Networks
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D, MaxPooling2D, GRU, LSTM, Embedding, Bidirectional
from tensorflow.keras.initializers import Constant
from tensorflow.keras.optimizers import Adam

# Import regularizers
from tensorflow.keras.regularizers import l2
# Import Dropout
from tensorflow.keras.layers import Dropout
# Import Early Stopping
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.utils import to_categorical, plot_model

# CNN imports 
import os
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# GridSearch imports 
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# RNN imports 
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator




# imports for reports on classification
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score

plt.style.use(style='seaborn')
# %matplotlib inline

# %% [markdown]
# ## Loading and Prepping the Data

# %%
# Loads the data
df = pd.read_csv('../../Data/reviews_stemmed_balanced.csv')
df.head()
# Out:
#               business_id                       name               review_id  \
# 0  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  wve8w6gIuPpCfo5J--AHjg
# 1  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  5rFuHGGbimVxPHxgM0sNSA
# 2  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  2iD3Rdbw0DUzjZSqBq3hXQ
# 3  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  e61y5ZlNwg04mAGtcD3vbQ
# 4  kZFTi8FKjs30EuzurZ3v3g             Donerick's Pub  38lN2ONaypsfBDLwhGxcSg
#
#    review_stars                                               text  \
# 0             3  The menu sounded promising, with over fifty di...
# 1             3  This wasn't the worst Chinese food but it wasn...
# 2             1  I have been coming to this restaurant for over...
# 3             5  My husband and I love this place.\nGreat price...
# 4             5  Great place for beverages with your friends wh...
#
#    amb_casual  amb_classy  amb_target  text_length  \
# 0         0.0         0.0           0          121
# 1         0.0         0.0           0           78
# 2         0.0         0.0           0           52
# 3         0.0         0.0           0           23
# 4         0.0         0.0           0           61
#
#                                           clean_text  clean_text_length  \
# 0  menu sounded promising fifty different dishes ...                 68
# 1  wasn' worst chinese food wasn' best egg foo yo...                 41
# 2  coming restaurant 20 years purchased shrimp fr...                 27
# 3  husband love place great price lot food make s...                 13
# 4  great place beverages friends watch game lots ...                 43
#
#                                      clean_text_stem  clean_text_stem_length
# 0  menu sound promis fifti differ dish differ sty...                      66
# 1  worst chines food best egg foo young dri overc...                      39
# 2  come restaur 20 year purchas shrimp fri rice g...                      26
# 3  husband love place great price lot food make s...                      12
# 4  great place beverag friend watch game lot tv g...                      43

# %% [markdown]
# ### Modeling with Tensorflow

# %%
# Sets up X and y
X = df['clean_text_stem']
y = df['amb_target']

# %%
# One-hot encoding for the categorical y response variable 
y = to_categorical(y)

# %%
# Splits the data into training and test sets from sample
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    stratify=y, 
                                                    random_state=42)

# %%
X_train
# Out:
# 8210     well final got around tri place like got meatl...
# 12491    love mohawk atmospher food outstand bad thing ...
# 55375    tri sever chines place powel worth mention twi...
# 34871    boyfriend stop dinner first night drive across...
# 17449    stop ice cream treat dinner main street love i...
#                                ...
# 47219    great food comfort atmospher food great gorgeo...
# 48987    bang buck price got awesom mediterrenean food ...
# 62754    two year want tri bibibop 5th avenu gv locat f...
# 25438    best servic small oper much staff partli accou...
# 26916    chicken avocado sandwich favorit mine none foo...
# Name: clean_text_stem, Length: 48650, dtype: object

# %% [markdown]
# ### Basic NLP

# %%
# import the Counter function
from collections import Counter

# import the tokenizer from keras preprocessing 
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Creates a function that counts unique words
def counter_word(text):
    count = Counter()
    for doc in text.values:
        for word in doc.split():
            count[word] += 1
    return count

# %%
X_train
# Out:
# 8210     well final got around tri place like got meatl...
# 12491    love mohawk atmospher food outstand bad thing ...
# 55375    tri sever chines place powel worth mention twi...
# 34871    boyfriend stop dinner first night drive across...
# 17449    stop ice cream treat dinner main street love i...
#                                ...
# 47219    great food comfort atmospher food great gorgeo...
# 48987    bang buck price got awesom mediterrenean food ...
# 62754    two year want tri bibibop 5th avenu gv locat f...
# 25438    best servic small oper much staff partli accou...
# 26916    chicken avocado sandwich favorit mine none foo...
# Name: clean_text_stem, Length: 48650, dtype: object

# %%
X_train.values[0]
# Out:
# 'well final got around tri place like got meatloaf melt fri ok wish would got someth els honest want get anyth adventur diner first time meatloaf fri flat top grill end dri result fri averag hot tea great although littl thing impress special day got bite chicken homemad noodl veggi still littl crunchi dish well done usual like sort thing friend pasta must pretti good say jack shit gone kind picki eater oh one thing legal tender challeng friend cash'

# %%
# Counts the number of times a unique word appears
counter = counter_word(X_train)

# %%
# Finds the length or the number of unique words
len(counter)
# Out:
# 28152

# %%
counter
# Out:
# Counter({'well': 9328,
#          'final': 2158,
#          'got': 11204,
#          'around': 4551,
#          'tri': 14488,
#          'place': 27839,
#          'like': 20121,
#          'meatloaf': 224,
#          'melt': 761,
#          'fri': 8257,
#          'ok': 2471,
#          'wish': 1716,
#          'would': 13236,
#          'someth': 4259,
#          'els': 2285,
#          'honest': 313,
#          'want': 8242,
#          'get': 18966,
#          'anyth': 2416,
#          'adventur': 222,
#          'diner': 932,
#          'first': 7564,
#          'time': 20971,
#          'flat': 333,
#          'top': 5639,
#          'grill': 1831,
#          'end': 2929,
#          'dri': 1584,
#          'result': 203,
#          'averag': 1338,
#          'hot': 5083,
#          'tea': 2046,
#          'great': 23526,
#          'although': 1391,
#          'littl': 7898,
#          'thing': 6135,
#          'impress': 2094,
#          'special': 4174,
#          'day': 5131,
#          'bite': 1772,
#          'chicken': 12839,
#          'homemad': 824,
#          'noodl': 1154,
#          'veggi': 1898,
#          'still': 4945,
#          'crunchi': 542,
#          'dish': 5133,
#          'done': 1825,
#          'usual': 2979,
#          'sort': 651,
#          'friend': 5860,
#          'pasta': 1429,
#          'must': 1865,
#          'pretti': 6918,
#          'good': 30478,
#          'say': 6032,
#          'jack': 171,
#          'shit': 169,
#          'gone': 894,
#          'kind': 2821,
#          'picki': 267,
#          'eater': 272,
#          'oh': 1680,
#          'one': 16150,
#          'legal': 24,
#          'tender': 1338,
#          'challeng': 173,
#          'cash': 389,
#          'love': 12639,
#          'mohawk': 164,
#          'atmospher': 4273,
#          'food': 36760,
#          'outstand': 921,
#          'bad': 4096,
#          'park': 3204,
#          'suck': 403,
#          'go': 18803,
#          'restaur': 12631,
#          'glad': 1144,
#          'sever': 2033,
#          'chines': 1780,
#          'powel': 189,
#          'worth': 3543,
#          'mention': 1177,
#          'twice': 1041,
#          'found': 2239,
#          'quit': 2463,
#          'tasti': 3467,
#          'favorit': 5332,
#          'sesam': 263,
#          'sweet': 3896,
#          'sour': 808,
#          'pork': 2372,
#          'also': 11415,
#          'start': 3116,
#          'deliveri': 1140,
#          'servic': 17295,
#          'best': 8973,
#          'boyfriend': 990,
#          'stop': 3670,
#          'dinner': 5505,
#          'night': 6248,
#          'drive': 2251,
#          'across': 841,
#          'countri': 369,
#          'back': 14539,
#          'california': 250,
#          'made': 6369,
#          'us': 9458,
#          'vegan': 931,
#          'everyth': 5331,
#          'soo': 54,
#          'amaz': 6780,
#          'delici': 9480,
#          'convert': 41,
#          'meat': 4210,
#          'instantli': 81,
#          'push': 231,
#          'vegetarian': 1123,
#          'crave': 878,
#          'ice': 2067,
#          'cream': 2081,
#          'treat': 1088,
#          'main': 1094,
#          'street': 1639,
#          'option': 4153,
#          'even': 9644,
#          'sandwich': 5985,
#          'knew': 811,
#          'appreci': 881,
#          'larg': 3016,
#          'plexiglass': 8,
#          'near': 945,
#          'regist': 419,
#          'keep': 1917,
#          'safe': 302,
#          'outdoor': 613,
#          'order': 25887,
#          'pick': 2343,
#          'prefer': 936,
#          'come': 10215,
#          '8': 1399,
#          'scoop': 185,
#          'challegeng': 1,
#          'went': 6774,
#          'lunch': 5184,
#          'chip': 2164,
#          'salsa': 1221,
#          'corn': 1099,
#          'enchilada': 185,
#          'look': 7926,
#          'small': 4314,
#          'plate': 2587,
#          'fill': 2141,
#          'servant': 5,
#          'friendli': 6966,
#          'effici': 442,
#          'busi': 4976,
#          'shorti': 12,
#          'expand': 153,
#          'delawar': 98,
#          'enjoy': 5522,
#          'carryout': 255,
#          'week': 2578,
#          'pizza': 9152,
#          'wing': 2677,
#          'sub': 1291,
#          'last': 3768,
#          'extend': 71,
#          'famili': 2701,
#          'two': 5564,
#          'extra': 1854,
#          'italian': 1465,
#          'promis': 285,
#          '20': 1886,
#          'min': 970,
#          'readi': 1318,
#          'home': 3152,
#          'fresh': 5966,
#          'staff': 7228,
#          'alway': 8702,
#          'greet': 1081,
#          'arriv': 2302,
#          'pickup': 277,
#          'sit': 3015,
#          'highli': 2186,
#          'recommend': 6215,
#          'mvp': 3,
#          'suprem': 96,
#          'pepperoni': 759,
#          'rel': 301,
#          'thin': 763,
#          'wafer': 14,
#          'new': 4520,
#          'york': 347,
#          'style': 1693,
#          'cover': 791,
#          'chees': 7624,
#          '8in': 1,
#          'full': 2795,
#          'insid': 2699,
#          'cool': 1917,
#          'definit': 7372,
#          'use': 3764,
#          'nice': 9515,
#          'bar': 8517,
#          'area': 4638,
#          'seat': 5092,
#          '12': 849,
#          '15': 1664,
#          'tabl': 8325,
#          'patio': 2389,
#          'bartend': 2068,
#          'plenti': 1674,
#          'front': 1690,
#          'plaza': 98,
#          'udf': 7,
#          'opposit': 92,
#          'thank': 1864,
#          'golden': 148,
#          'china': 131,
#          'daughter': 615,
#          'takeout': 511,
#          'hilliard': 315,
#          'pleas': 1477,
#          'choic': 2173,
#          'qualiti': 3556,
#          'high': 2851,
#          'flavor': 7301,
#          'profil': 86,
#          'portion': 3288,
#          'size': 2298,
#          'price': 8011,
#          'point': 2178,
#          'agreeabl': 4,
#          'kung': 84,
#          'pao': 69,
#          'egg': 3271,
#          'roll': 3450,
#          'crab': 1262,
#          'rangoon': 373,
#          'steam': 392,
#          'dumpl': 560,
#          'stood': 325,
#          'rest': 858,
#          'excel': 4004,
#          'textur': 612,
#          'amount': 1628,
#          'truli': 650,
#          'columbu': 6825,
#          'find': 3640,
#          'shrimp': 2457,
#          'frozen': 503,
#          'potato': 3025,
#          'eddi': 120,
#          'bland': 1135,
#          'steak': 3241,
#          'bourbon': 410,
#          'ribey': 190,
#          'fatti': 159,
#          'cut': 1262,
#          'correctli': 163,
#          'cake': 1532,
#          'clearli': 563,
#          'without': 2192,
#          'drink': 9872,
#          'total': 1447,
#          'bill': 1133,
#          '95': 196,
#          '1': 3010,
#          'person': 2788,
#          'mouth': 825,
#          'water': 1920,
#          'let': 2540,
#          'especi': 1978,
#          'breakfast': 2981,
#          'attract': 171,
#          'obvious': 504,
#          'okonomiyaki': 7,
#          'though': 4058,
#          'authent': 1366,
#          'need': 4488,
#          'could': 6555,
#          'bring': 1898,
#          'young': 567,
#          'children': 244,
#          'meet': 759,
#          'state': 706,
#          'complet': 1258,
#          'incorrect': 113,
#          'item': 2807,
#          'left': 2459,
#          'hostess': 878,
#          'combo': 694,
#          'packag': 181,
#          'save': 691,
#          'money': 1447,
#          'polit': 587,
#          'counter': 1321,
#          'explain': 772,
#          'issu': 1223,
#          'ask': 6576,
#          'receipt': 245,
#          'never': 6812,
#          'gave': 1875,
#          'care': 1910,
#          '2': 5017,
#          'differ': 3432,
#          'employe': 1637,
#          'manag': 3619,
#          'forth': 84,
#          'print': 95,
#          'origin': 680,
#          'agre': 481,
#          'void': 27,
#          'recharg': 3,
#          'offer': 3223,
#          'consider': 98,
#          'chang': 1663,
#          'cost': 754,
#          'help': 2992,
#          'make': 8778,
#          'group': 1999,
#          'train': 344,
#          'custom': 3950,
#          'sure': 4912,
#          'job': 1054,
#          'experi': 6545,
#          'particular': 402,
#          'anyon': 1292,
#          'unhappi': 68,
#          'fun': 2303,
#          'kid': 1965,
#          'neighborhood': 779,
#          'al': 720,
#          'happi': 4289,
#          'hour': 5078,
#          'awesom': 3424,
#          'limit': 799,
#          'menu': 9832,
#          'eclect': 130,
#          'mix': 1536,
#          'crowd': 1672,
#          'not': 1,
#          'welcom': 1036,
#          'folk': 475,
#          'carri': 849,
#          'multipli': 4,
#          'estim': 70,
#          'howev': 2883,
#          'burger': 4758,
#          'huge': 2450,
#          'much': 6679,
#          'second': 1839,
#          'walk': 3627,
#          'brought': 1805,
#          'town': 2591,
#          'styliz': 2,
#          'ikea': 15,
#          'three': 1986,
#          'star': 4808,
#          'show': 1438,
#          'carrot': 526,
#          'enough': 3323,
#          'think': 5456,
#          'everi': 4101,
#          'im': 208,
#          'disappoint': 4381,
#          'mayb': 2541,
#          'pricier': 108,
#          'truck': 855,
#          'consist': 1349,
#          'serv': 5010,
#          'taco': 4173,
#          'tast': 7826,
#          '75': 195,
#          'valu': 697,
#          'noth': 2892,
#          'fanci': 591,
#          'stuff': 999,
#          'quesadilla': 473,
#          'torta': 192,
#          'jarito': 1,
#          'soda': 449,
#          'protein': 345,
#          'squeez': 173,
#          'sriracha': 113,
#          'finish': 1399,
#          'bloodi': 343,
#          'orang': 408,
#          'margarita': 767,
#          'colleg': 328,
#          'student': 213,
#          'budget': 91,
#          'gotten': 628,
#          'anoth': 3844,
#          'johnni': 60,
#          'server': 5939,
#          'prompt': 399,
#          'take': 6011,
#          'deliv': 1035,
#          '3': 4053,
#          'deduct': 43,
#          'brussel': 432,
#          'sprout': 583,
#          'yum': 1063,
#          'cheeseburg': 289,
#          'son': 670,
#          'bacon': 2030,
#          'stir': 101,
#          'greasi': 753,
#          'wrap': 1070,
#          'transluc': 6,
#          'tablespoon': 15,
#          'mayo': 364,
#          'ketchup': 228,
#          'mixtur': 113,
#          'drip': 131,
#          'side': 5916,
#          'worst': 1204,
#          'ever': 4967,
#          'wendi': 271,
#          'gener': 1891,
#          'cannot': 671,
#          'brag': 49,
#          'believ': 1096,
#          'sushi': 2055,
#          'mean': 1390,
#          'clean': 2809,
#          'classi': 318,
#          'absolut': 2505,
#          'impecc': 163,
#          'cincinnati': 165,
#          'visit': 5526,
#          'seem': 4437,
#          'imposs': 168,
#          'figur': 625,
#          'lot': 5419,
#          'behind': 991,
#          'build': 920,
#          'sinc': 3953,
#          'head': 1051,
#          'give': 5086,
#          'spot': 3494,
#          'chanc': 782,
#          'better': 5626,
#          'moment': 322,
#          'invit': 392,
#          'harder': 41,
#          'leav': 1919,
#          'comfort': 1123,
#          'mind': 1119,
#          'bump': 108,
#          'music': 1310,
#          'sound': 796,
#          'blare': 27,
#          'took': 3885,
#          'eye': 623,
#          'candi': 192,
#          'way': 5307,
#          'view': 632,
#          'form': 202,
#          'previou': 326,
#          'review': 4232,
#          'chore': 15,
#          'forward': 891,
#          'next': 3869,
#          'cafe': 882,
#          'strip': 686,
#          'mall': 485,
#          'cours': 1529,
#          'interior': 652,
#          'mani': 4025,
#          'peopl': 6253,
#          'expect': 3640,
#          'may': 1686,
#          'feel': 4047,
#          'actual': 2727,
#          'stay': 1227,
#          'fine': 1600,
#          'dine': 3331,
#          'liquor': 253,
#          'japanes': 262,
#          'hunan': 67,
#          'bean': 1796,
#          'curd': 147,
#          '9': 960,
#          'regular': 1622,
#          'proud': 71,
#          'room': 2146,
#          'big': 3170,
#          'eaten': 1081,
#          'other': 1004,
#          'realli': 12927,
#          'admittedli': 50,
#          'low': 696,
#          'multipl': 602,
#          'chose': 620,
#          'salad': 7005,
#          'run': 1526,
#          'genuin': 225,
#          'knowledg': 666,
#          'tell': 2219,
#          'gem': 734,
#          'addit': 1061,
#          'villag': 525,
#          'overlook': 130,
#          'pro': 215,
#          'trendi': 309,
#          'decor': 1808,
#          'check': 3877,
#          'book': 564,
#          'write': 766,
#          'thought': 2481,
#          'okay': 1553,
#          'stuf': 693,
#          'ravioli': 250,
#          'lack': 1183,
#          'husband': 2769,
#          'con': 225,
#          'close': 2557,
#          'togeth': 1027,
#          'awkward': 197,
#          'bc': 185,
#          'hear': 833,
#          'convers': 635,
#          'right': 4932,
#          'glass': 1439,
#          'wine': 3246,
#          'notic': 1077,
#          'creativ': 337,
#          'blend': 317,
#          'classic': 704,
#          'craft': 558,
#          'cocktail': 2225,
#          'often': 1435,
#          'spirit': 126,
#          'nyc': 185,
#          'live': 2377,
#          'bagel': 783,
#          'wet': 136,
#          'nap': 38,
#          'hershey': 14,
#          'kiss': 41,
#          'excit': 1159,
#          'surpris': 1610,
#          'kill': 200,
#          'guy': 1903,
#          'weekend': 1434,
#          'case': 618,
#          'wait': 9605,
#          'least': 1863,
#          '6': 1838,
#          'parti': 1835,
#          'told': 3049,
#          'empti': 877,
#          'gossip': 12,
#          'station': 355,
#          'nowher': 113,
#          'sight': 94,
#          'remain': 206,
#          'meanwhil': 35,
#          'long': 3685,
#          'satisfact': 56,
#          'excus': 268,
#          'poor': 829,
#          'minu': 102,
#          'score': 152,
#          'see': 3905,
#          'pride': 159,
#          'work': 4469,
#          'own': 385,
#          'meal': 7081,
#          'shawarma': 154,
#          'grape': 147,
#          'greek': 1106,
#          'baba': 178,
#          'ghanoush': 27,
#          'hummu': 846,
#          'tahini': 64,
#          'sauc': 8158,
#          'feta': 351,
#          'unabl': 100,
#          'anywher': 628,
#          'cleveland': 189,
#          'list': 1428,
#          'guess': 1113,
#          'jimmi': 104,
#          'john': 199,
#          'wife': 2113,
#          'spring': 509,
#          'saturday': 1556,
#          'sick': 263,
#          'subway': 153,
#          'joint': 797,
#          'argu': 132,
#          'eat': 8023,
#          'hand': 1991,
#          'seek': 85,
#          'question': 735,
#          'shop': 1487,
#          'certain': 298,
#          'protocol': 29,
#          'handl': 444,
#          'driven': 97,
#          'yet': 1538,
#          'stick': 847,
#          'suppos': 661,
#          'will': 347,
#          'strong': 553,
#          'reason': 2989,
#          'ie': 33,
#          'someon': 1727,
#          'girlfriend': 512,
#          'mine': 671,
#          'arrang': 75,
#          'hang': 665,
#          'derbi': 12,
#          'locat': 6182,
#          'flip': 214,
#          'year': 3558,
#          'hope': 1826,
#          'awhil': 430,
#          'mediterranean': 530,
#          'sunset': 32,
#          'holi': 358,
#          'cow': 82,
#          'calamari': 717,
#          'divin': 137,
#          'kabob': 146,
#          'share': 1639,
#          'overal': 3011,
#          'pleasantli': 374,
#          'event': 821,
#          'oppos': 90,
#          'self': 288,
#          'super': 3572,
#          'jay': 62,
#          'posit': 452,
#          'know': 5404,
#          'rememb': 1227,
#          'name': 1739,
#          'normal': 1068,
#          '5': 4898,
#          'firebird': 94,
#          'buy': 741,
#          'joe': 242,
#          'tommi': 40,
#          'bought': 322,
#          '30th': 26,
#          'slice': 1407,
#          'realiz': 711,
#          'far': 1905,
#          'accustom': 33,
#          'call': 3210,
#          'spoke': 203,
#          'owner': 2046,
#          'less': 1547,
#          'laudatori': 1,
#          'return': 2401,
#          'per': 463,
#          'instruct': 97,
#          'receiv': 1388,
#          'replac': 332,
#          'prepar': 1520,
#          'speak': 638,
#          'frown': 14,
#          'frighten': 6,
#          'angrili': 14,
#          'manner': 177,
#          'encount': 140,
#          'unprofession': 148,
#          'extrem': 1533,
#          'unnerv': 2,
#          'unspeak': 3,
#          'race': 82,
#          'desir': 288,
#          'trash': 203,
#          'vow': 18,
#          'healthi': 723,
#          'gluten': 826,
#          'free': 2844,
#          'north': 1969,
#          'market': 1447,
#          'combin': 644,
#          'choos': 1160,
#          'decent': 2193,
#          '10': 3603,
#          'half': 2807,
#          'match': 288,
#          'varieti': 1425,
#          'tradit': 765,
#          'indian': 738,
#          'entre': 1946,
#          'heap': 53,
#          'basmati': 21,
#          'rice': 3214,
#          'allow': 465,
#          'sampl': 831,
#          'cheaper': 293,
#          'okra': 42,
#          'green': 1624,
#          'dal': 40,
#          'yummi': 1184,
#          'spici': 3520,
#          'intend': 100,
#          'pack': 1341,
#          'takeov': 212,
#          'destin': 157,
#          'donut': 1456,
#          'asian': 734,
#          'inspir': 154,
#          'lemongrass': 227,
#          'phenomen': 505,
#          'waiter': 2022,
#          'chic': 80,
#          'elev': 276,
#          'tighten': 5,
#          'game': 1906,
#          'interest': 1087,
#          'local': 2298,
#          'beer': 4707,
#          'unfortun': 991,
#          'par': 352,
#          'bag': 757,
#          'shrivel': 12,
#          'piec': 1667,
#          'bottom': 456,
#          'likewis': 18,
#          'fail': 279,
#          'potenti': 166,
#          'came': 7374,
#          'breast': 317,
#          'bread': 4224,
#          'thick': 737,
#          'heavi': 499,
#          'curious': 5,
#          'restrict': 104,
#          'p': 230,
#          'standout': 82,
#          'signatur': 277,
#          'ale': 244,
#          'barleywin': 1,
#          'passabl': 36,
#          'whole': 1682,
#          'kept': 867,
#          'imagin': 436,
#          'gordon': 20,
#          'ramsay': 9,
#          'burst': 70,
#          'revamp': 23,
#          'whip': 221,
#          'kitchen': 1437,
#          'shape': 145,
#          'futur': 462,
#          'skip': 384,
#          'hr': 65,
#          '4th': 131,
#          'juli': 77,
#          'eagl': 366,
#          'tonight': 1023,
#          'short': 2222,
#          'born': 48,
#          'tennesse': 13,
#          'southern': 292,
#          'girl': 940,
#          'heart': 460,
#          'satisfi': 780,
#          '4': 3379,
#          'among': 218,
#          'four': 993,
#          'collard': 175,
#          'spoon': 284,
#          'biscuit': 726,
#          'mac': 2122,
#          'n': 837,
#          'succotash': 29,
#          'cant': 184,
#          'modern': 434,
#          'bare': 600,
#          'move': 1477,
#          'summer': 668,
#          'u': 230,
#          'anybodi': 73,
#          '11': 611,
#          'cheap': 1114,
#          'warn': 266,
#          'shot': 514,
#          'tall': 109,
#          'pint': 205,
#          'plan': 925,
#          'accordingli': 55,
#          'brat': 42,
#          'dog': 480,
#          'wha': 5,
#          'ohio': 1269,
#          'theater': 190,
#          'pearl': 374,
#          'space': 1546,
#          'except': 1229,
#          'select': 3221,
#          'answer': 602,
#          'appet': 2977,
#          'jalapeno': 261,
#          'kick': 563,
#          'sausag': 1082,
#          'sampler': 276,
#          'ladi': 857,
#          'split': 851,
#          'grit': 282,
#          'cinnamon': 630,
#          'role': 54,
#          'rib': 1514,
#          'memor': 204,
#          'regularli': 195,
#          'beat': 579,
#          '7': 1408,
#          'crispi': 1586,
#          'honey': 622,
#          'red': 1602,
#          'die': 676,
#          'berri': 136,
#          'jam': 322,
#          'butter': 1135,
#          'skillet': 207,
#          'aioli': 179,
#          'mapl': 200,
#          'infus': 80,
#          'cornbread': 236,
#          'depend': 262,
#          'floor': 714,
#          'picnic': 126,
#          'ago': 1164,
#          'sat': 1770,
#          'avail': 1044,
#          'covid': 392,
#          'wear': 396,
#          'mask': 275,
#          'fall': 486,
#          'guest': 589,
#          'shoulder': 97,
#          'add': 1426,
#          'hook': 158,
#          'set': 1269,
#          'cleanest': 37,
#          'old': 2499,
#          'booster': 14,
#          'booth': 651,
#          'easili': 653,
#          'slide': 71,
#          'knee': 26,
#          'typic': 1160,
#          'fan': 1779,
#          'adult': 310,
#          'quick': 2173,
#          'bathroom': 679,
#          'minut': 5810,
#          'meter': 133,
#          'follow': 550,
#          'bake': 1130,
#          'satan': 2,
#          'sammich': 38,
#          'freakin': 46,
#          'open': 3660,
#          'nearer': 6,
#          'huzzah': 3,
#          'reserv': 2170,
#          'earli': 1072,
#          'heather': 8,
#          'fantast': 2519,
#          'tuna': 628,
#          'mahi': 127,
#          'linguini': 28,
#          'perfectli': 1791,
#          'pipe': 179,
#          'seven': 133,
#          'middl': 669,
#          'wrong': 1912,
#          'juici': 675,
#          'horseradish': 108,
#          'mash': 611,
#          'hole': 323,
#          'wall': 982,
#          'probabl': 2745,
#          'wast': 545,
#          'stumbl': 162,
#          'upon': 646,
#          'vibe': 1003,
#          'relax': 596,
#          'color': 418,
#          'cozi': 572,
#          'cuban': 372,
#          'entri': 94,
#          'calzon': 139,
#          'includ': 1659,
#          'true': 514,
#          'suffic': 29,
#          'mexican': 1477,
#          'la': 450,
#          'fogata': 18,
#          'franchis': 117,
#          'concept': 522,
#          'accompani': 300,
#          'stellar': 217,
#          'friendliest': 56,
#          'wonder': 2797,
#          'given': 1115,
#          'extens': 275,
#          'bakersfield': 24,
#          'establish': 959,
#          'cinci': 54,
#          'rhine': 2,
#          'heard': 1108,
#          'everyon': 2435,
#          'killer': 149,
#          'honestli': 975,
#          'base': 1213,
#          'sole': 107,
#          'prep': 121,
#          'method': 41,
#          'spicier': 90,
#          'crunchier': 4,
#          'cajun': 289,
#          'heavili': 79,
#          'fatten': 10,
#          'drizzl': 193,
#          'ooz': 39,
#          'oil': 749,
#          'yeah': 404,
#          'popey': 57,
#          'funni': 292,
#          'trashi': 15,
#          'ahead': 694,
#          'judg': 197,
#          'rang': 357,
#          'boneless': 326,
#          'hearti': 169,
#          'tap': 539,
#          'draft': 539,
#          'bottl': 1037,
#          'diversifi': 9,
#          'pay': 1882,
#          'variou': 293,
#          'rather': 983,
#          '4oz': 12,
#          'easi': 1144,
#          'warmer': 158,
#          'weather': 380,
#          'decid': 2695,
#          'due': 958,
#          'indoor': 218,
#          'orlean': 108,
#          'coffe': 3242,
#          'refresh': 400,
#          'banana': 729,
#          'firm': 62,
#          'bit': 4676,
#          'sweeter': 85,
#          'opinion': 623,
#          'neither': 267,
#          'commun': 533,
#          'alcohol': 421,
#          'appl': 487,
#          'martini': 388,
#          'later': 1441,
#          'abl': 1449,
#          'line': 2806,
#          'steakhous': 369,
#          'cowboy': 64,
#          'sad': 553,
#          'roadhous': 76,
#          'slightli': 741,
#          'burnt': 437,
#          '71': 29,
#          'cook': 4156,
#          'perfect': 4076,
#          'asparagu': 260,
#          'fact': 1051,
#          'sold': 264,
#          'separ': 455,
#          'à': 7,
#          'cart': 275,
#          'lobster': 900,
#          'bisqu': 374,
#          'soup': 3213,
#          'hidden': 481,
#          'partaken': 3,
#          'domin': 43,
#          'crap': 210,
#          'talk': 1479,
#          'seafood': 943,
#          'world': 762,
#          'obx': 2,
#          'fell': 277,
#          'fish': 2244,
#          'ocean': 48,
#          'soft': 879,
#          'shell': 265,
#          'part': 1771,
#          'frank': 130,
#          ...})

# %% [markdown]
# #### Define max number of words in a sequence
# * Setting this max number is important because we need to define a maximum sequence length that we can set to a number we pick
# * Note: Depending on the text, it is better to set this number high
# * (ex: Tweet - it is better to set this number to a high number between 50-70)
# * (ex: bigger text - you can set it to 200 or more)
# * In our trial, we're just going to start off small with 50 words
#
# The reason we need to define the sequence length is because when we use it with Tensorflow, we're going to need the same number of words/sequence length for each sequence.
#
# We won't be able to have sequences of different lengths. We need to map them to the same sequence size.

# %%
num_words = len(counter)

# Max number of words in a sequence
max_length = 50

# %% [markdown]
# #### Use the Tokenizer Class
#
# The next thing we need to use is the Tokenizer class from keras to tokenize the train sentences

# %%
# import the tokenizer from keras preprocessing 
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Fit the tokenizer onto the train sentences 
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(X_train)

# %%
# Pulls the word index from the tokenizer 
word_index = tokenizer.word_index

# This is an attribute of the tokenizer
# The attribute is a dictionary where
# key = actual word 
# value = the number that will now represent that word

# %%
word_index
# Out:
# {'food': 1,
#  'good': 2,
#  'place': 3,
#  'order': 4,
#  'great': 5,
#  'time': 6,
#  'like': 7,
#  'get': 8,
#  'go': 9,
#  'servic': 10,
#  'one': 11,
#  'back': 12,
#  'tri': 13,
#  'would': 14,
#  'realli': 15,
#  'chicken': 16,
#  'love': 17,
#  'restaur': 18,
#  'also': 19,
#  'got': 20,
#  'come': 21,
#  'drink': 22,
#  'menu': 23,
#  'even': 24,
#  'wait': 25,
#  'nice': 26,
#  'delici': 27,
#  'us': 28,
#  'well': 29,
#  'pizza': 30,
#  'best': 31,
#  'make': 32,
#  'alway': 33,
#  'bar': 34,
#  'tabl': 35,
#  'fri': 36,
#  'want': 37,
#  'sauc': 38,
#  'eat': 39,
#  'price': 40,
#  'look': 41,
#  'littl': 42,
#  'tast': 43,
#  'chees': 44,
#  'first': 45,
#  'came': 46,
#  'definit': 47,
#  'flavor': 48,
#  'staff': 49,
#  'meal': 50,
#  'salad': 51,
#  'friendli': 52,
#  'pretti': 53,
#  'columbu': 54,
#  'never': 55,
#  'amaz': 56,
#  'went': 57,
#  'much': 58,
#  'ask': 59,
#  'could': 60,
#  'experi': 61,
#  'made': 62,
#  'peopl': 63,
#  'night': 64,
#  'recommend': 65,
#  'locat': 66,
#  'thing': 67,
#  'say': 68,
#  'take': 69,
#  'sandwich': 70,
#  'fresh': 71,
#  'server': 72,
#  'side': 73,
#  'friend': 74,
#  'minut': 75,
#  'top': 76,
#  'better': 77,
#  'two': 78,
#  'visit': 79,
#  'enjoy': 80,
#  'dinner': 81,
#  'think': 82,
#  'lot': 83,
#  'know': 84,
#  'favorit': 85,
#  'everyth': 86,
#  'way': 87,
#  'lunch': 88,
#  'dish': 89,
#  'day': 90,
#  'seat': 91,
#  'give': 92,
#  'hot': 93,
#  'hour': 94,
#  '2': 95,
#  'serv': 96,
#  'busi': 97,
#  'ever': 98,
#  'still': 99,
#  'right': 100,
#  'said': 101,
#  'sure': 102,
#  '5': 103,
#  'star': 104,
#  'burger': 105,
#  'beer': 106,
#  'bit': 107,
#  'area': 108,
#  'around': 109,
#  'new': 110,
#  'need': 111,
#  'work': 112,
#  'seem': 113,
#  'disappoint': 114,
#  'small': 115,
#  'happi': 116,
#  'atmospher': 117,
#  'someth': 118,
#  'review': 119,
#  'bread': 120,
#  'meat': 121,
#  'special': 122,
#  'taco': 123,
#  'cook': 124,
#  'option': 125,
#  'everi': 126,
#  'bad': 127,
#  'perfect': 128,
#  'though': 129,
#  '3': 130,
#  'feel': 131,
#  'mani': 132,
#  'excel': 133,
#  'sinc': 134,
#  'custom': 135,
#  'see': 136,
#  'sweet': 137,
#  'took': 138,
#  'check': 139,
#  'next': 140,
#  'anoth': 141,
#  'last': 142,
#  'use': 143,
#  'long': 144,
#  'stop': 145,
#  'open': 146,
#  'find': 147,
#  'expect': 148,
#  'walk': 149,
#  'manag': 150,
#  '10': 151,
#  'super': 152,
#  'year': 153,
#  'qualiti': 154,
#  'worth': 155,
#  'spici': 156,
#  'spot': 157,
#  'tasti': 158,
#  'roll': 159,
#  'differ': 160,
#  'awesom': 161,
#  '4': 162,
#  'dine': 163,
#  'enough': 164,
#  'portion': 165,
#  'egg': 166,
#  'wine': 167,
#  'coffe': 168,
#  'steak': 169,
#  'offer': 170,
#  'select': 171,
#  'rice': 172,
#  'soup': 173,
#  'call': 174,
#  'park': 175,
#  'big': 176,
#  'home': 177,
#  'start': 178,
#  'told': 179,
#  'potato': 180,
#  'larg': 181,
#  'sit': 182,
#  'overal': 183,
#  '1': 184,
#  'help': 185,
#  'reason': 186,
#  'breakfast': 187,
#  'usual': 188,
#  'appet': 189,
#  'end': 190,
#  'noth': 191,
#  'howev': 192,
#  'high': 193,
#  'free': 194,
#  'kind': 195,
#  'clean': 196,
#  'item': 197,
#  'half': 198,
#  'line': 199,
#  'wonder': 200,
#  'full': 201,
#  'person': 202,
#  'husband': 203,
#  'probabl': 204,
#  'fast': 205,
#  'actual': 206,
#  'famili': 207,
#  'insid': 208,
#  'decid': 209,
#  'wing': 210,
#  'town': 211,
#  'plate': 212,
#  'week': 213,
#  'bowl': 214,
#  'close': 215,
#  'waitress': 216,
#  'away': 217,
#  'mayb': 218,
#  'let': 219,
#  'fantast': 220,
#  'absolut': 221,
#  'old': 222,
#  'dessert': 223,
#  'hous': 224,
#  'thought': 225,
#  'put': 226,
#  'ok': 227,
#  'quit': 228,
#  'left': 229,
#  'shrimp': 230,
#  'huge': 231,
#  'everyon': 232,
#  'cold': 233,
#  'anyth': 234,
#  'return': 235,
#  'patio': 236,
#  'live': 237,
#  'pork': 238,
#  'attent': 239,
#  'pick': 240,
#  'fun': 241,
#  'arriv': 242,
#  'size': 243,
#  'local': 244,
#  'els': 245,
#  'drive': 246,
#  'fish': 247,
#  'found': 248,
#  'cocktail': 249,
#  'short': 250,
#  'tell': 251,
#  'decent': 252,
#  'without': 253,
#  'highli': 254,
#  'point': 255,
#  'choic': 256,
#  'quick': 257,
#  'reserv': 258,
#  'chip': 259,
#  'final': 260,
#  'room': 261,
#  'fill': 262,
#  'almost': 263,
#  'mac': 264,
#  'hard': 265,
#  'wife': 266,
#  'impress': 267,
#  'coupl': 268,
#  'cream': 269,
#  'beef': 270,
#  'bartend': 271,
#  'ice': 272,
#  'sushi': 273,
#  'outsid': 274,
#  'onion': 275,
#  'tea': 276,
#  'owner': 277,
#  'warm': 278,
#  'sever': 279,
#  'bacon': 280,
#  'waiter': 281,
#  'group': 282,
#  'hand': 283,
#  'three': 284,
#  'season': 285,
#  'especi': 286,
#  'north': 287,
#  'kid': 288,
#  'entre': 289,
#  'water': 290,
#  'leav': 291,
#  'keep': 292,
#  'cool': 293,
#  'wrong': 294,
#  'care': 295,
#  'game': 296,
#  'far': 297,
#  'guy': 298,
#  'veggi': 299,
#  'bring': 300,
#  'gener': 301,
#  'door': 302,
#  '30': 303,
#  '20': 304,
#  'pay': 305,
#  'gave': 306,
#  'must': 307,
#  'thank': 308,
#  'least': 309,
#  'extra': 310,
#  'second': 311,
#  '6': 312,
#  'parti': 313,
#  'grill': 314,
#  'hope': 315,
#  'done': 316,
#  'today': 317,
#  'decor': 318,
#  'brought': 319,
#  'bean': 320,
#  'perfectli': 321,
#  'chines': 322,
#  'fan': 323,
#  'bite': 324,
#  'part': 325,
#  'sat': 326,
#  'name': 327,
#  'someon': 328,
#  'light': 329,
#  'wish': 330,
#  'brunch': 331,
#  'crust': 332,
#  'style': 333,
#  'front': 334,
#  'may': 335,
#  'whole': 336,
#  'oh': 337,
#  'plenti': 338,
#  'crowd': 339,
#  'piec': 340,
#  '15': 341,
#  'chang': 342,
#  'includ': 343,
#  'street': 344,
#  'share': 345,
#  'employe': 346,
#  'amount': 347,
#  'green': 348,
#  'regular': 349,
#  'slow': 350,
#  'surpris': 351,
#  'red': 352,
#  'fine': 353,
#  'instead': 354,
#  'either': 355,
#  'crispi': 356,
#  'dri': 357,
#  'saturday': 358,
#  'okay': 359,
#  'less': 360,
#  'space': 361,
#  'ate': 362,
#  'yet': 363,
#  'mix': 364,
#  'store': 365,
#  'extrem': 366,
#  'cake': 367,
#  'cours': 368,
#  'citi': 369,
#  'run': 370,
#  'prepar': 371,
#  'rib': 372,
#  'might': 373,
#  'miss': 374,
#  'felt': 375,
#  'shop': 376,
#  'talk': 377,
#  'pleas': 378,
#  'move': 379,
#  'mexican': 380,
#  'white': 381,
#  'spice': 382,
#  'pepper': 383,
#  'italian': 384,
#  'deal': 385,
#  'quickli': 386,
#  'donut': 387,
#  'abl': 388,
#  'thai': 389,
#  'total': 390,
#  'money': 391,
#  'market': 392,
#  'incred': 393,
#  'later': 394,
#  'glass': 395,
#  'show': 396,
#  'kitchen': 397,
#  'often': 398,
#  'ingredi': 399,
#  'weekend': 400,
#  'beauti': 401,
#  'dress': 402,
#  'pasta': 403,
#  'list': 404,
#  'add': 405,
#  'varieti': 406,
#  'watch': 407,
#  'tomato': 408,
#  'sunday': 409,
#  'real': 410,
#  '7': 411,
#  'slice': 412,
#  'date': 413,
#  '8': 414,
#  'finish': 415,
#  'although': 416,
#  'mean': 417,
#  'receiv': 418,
#  'gyro': 419,
#  'french': 420,
#  'authent': 421,
#  'dip': 422,
#  'ye': 423,
#  'consist': 424,
#  'pack': 425,
#  'averag': 426,
#  'tender': 427,
#  'suggest': 428,
#  'soon': 429,
#  'past': 430,
#  'counter': 431,
#  'readi': 432,
#  'tip': 433,
#  'music': 434,
#  'salmon': 435,
#  'late': 436,
#  'play': 437,
#  'anyon': 438,
#  'sub': 439,
#  'birthday': 440,
#  'terribl': 441,
#  'ad': 442,
#  'ohio': 443,
#  'set': 444,
#  'bbq': 445,
#  'crab': 446,
#  'cut': 447,
#  'complet': 448,
#  'happen': 449,
#  'problem': 450,
#  'except': 451,
#  'stay': 452,
#  'rememb': 453,
#  'issu': 454,
#  'salsa': 455,
#  'base': 456,
#  'uniqu': 457,
#  'toast': 458,
#  'friday': 459,
#  'worst': 460,
#  'type': 461,
#  'chocol': 462,
#  'stand': 463,
#  'burrito': 464,
#  'chipotl': 465,
#  'charg': 466,
#  'yummi': 467,
#  'lack': 468,
#  'recent': 469,
#  'mention': 470,
#  'rude': 471,
#  'saw': 472,
#  'ago': 473,
#  'sometim': 474,
#  'choos': 475,
#  'typic': 476,
#  'excit': 477,
#  'hit': 478,
#  'alreadi': 479,
#  'noodl': 480,
#  'plu': 481,
#  'ambianc': 482,
#  'turn': 483,
#  'glad': 484,
#  'easi': 485,
#  'deliveri': 486,
#  'entir': 487,
#  'yelp': 488,
#  'bland': 489,
#  'butter': 490,
#  'garlic': 491,
#  'bill': 492,
#  'bake': 493,
#  'vegetarian': 494,
#  'comfort': 495,
#  'mind': 496,
#  'month': 497,
#  'given': 498,
#  'cup': 499,
#  'cheap': 500,
#  'guess': 501,
#  'trip': 502,
#  'heard': 503,
#  'greek': 504,
#  'corn': 505,
#  'believ': 506,
#  'main': 507,
#  'pie': 508,
#  'treat': 509,
#  'interest': 510,
#  'grab': 511,
#  'sausag': 512,
#  'pho': 513,
#  'greet': 514,
#  'eaten': 515,
#  'notic': 516,
#  '50': 517,
#  'earli': 518,
#  'expens': 519,
#  'buffet': 520,
#  'wrap': 521,
#  'normal': 522,
#  'veget': 523,
#  'yum': 524,
#  'wow': 525,
#  'addit': 526,
#  'basic': 527,
#  'chef': 528,
#  'job': 529,
#  'understand': 530,
#  'head': 531,
#  'fact': 532,
#  'avail': 533,
#  'five': 534,
#  'twice': 535,
#  'bottl': 536,
#  'welcom': 537,
#  'read': 538,
#  'deliv': 539,
#  'simpl': 540,
#  'togeth': 541,
#  'tonight': 542,
#  'mushroom': 543,
#  'pickl': 544,
#  'rate': 545,
#  'other': 546,
#  'vibe': 547,
#  'stuff': 548,
#  'four': 549,
#  'brisket': 550,
#  'behind': 551,
#  'unfortun': 552,
#  'boyfriend': 553,
#  'rather': 554,
#  'wall': 555,
#  'honestli': 556,
#  'lamb': 557,
#  'min': 558,
#  'standard': 559,
#  '9': 560,
#  'establish': 561,
#  'medium': 562,
#  'due': 563,
#  'liter': 564,
#  'pricey': 565,
#  'morn': 566,
#  'horribl': 567,
#  'window': 568,
#  'near': 569,
#  'along': 570,
#  'seafood': 571,
#  'etc': 572,
#  'pull': 573,
#  'girl': 574,
#  'solid': 575,
#  'chain': 576,
#  'black': 577,
#  'prefer': 578,
#  'pita': 579,
#  'diner': 580,
#  'vegan': 581,
#  'level': 582,
#  'plan': 583,
#  'downtown': 584,
#  'loud': 585,
#  'outstand': 586,
#  'roast': 587,
#  'build': 588,
#  'card': 589,
#  'complaint': 590,
#  'consid': 591,
#  'phone': 592,
#  'serious': 593,
#  'casual': 594,
#  'salt': 595,
#  'lobster': 596,
#  'gone': 597,
#  'forward': 598,
#  'cafe': 599,
#  'appreci': 600,
#  'soft': 601,
#  'heat': 602,
#  'crave': 603,
#  'hostess': 604,
#  'empti': 605,
#  'lettuc': 606,
#  'immedi': 607,
#  'kept': 608,
#  'salti': 609,
#  'life': 610,
#  'rest': 611,
#  'ladi': 612,
#  'hungri': 613,
#  'truck': 614,
#  'split': 615,
#  '12': 616,
#  'carri': 617,
#  'stick': 618,
#  'hummu': 619,
#  'refil': 620,
#  'across': 621,
#  'bun': 622,
#  'brown': 623,
#  'n': 624,
#  'thru': 625,
#  'seen': 626,
#  'hear': 627,
#  'meatbal': 628,
#  'pleasant': 629,
#  'sampl': 630,
#  'onlin': 631,
#  'poor': 632,
#  'note': 633,
#  'paid': 634,
#  'gluten': 635,
#  'man': 636,
#  'mouth': 637,
#  'homemad': 638,
#  'anyway': 639,
#  'rare': 640,
#  'event': 641,
#  'app': 642,
#  'pastor': 643,
#  'knew': 644,
#  'sour': 645,
#  'pancak': 646,
#  'limit': 647,
#  'sign': 648,
#  'cute': 649,
#  'joint': 650,
#  'sound': 651,
#  'cover': 652,
#  'ton': 653,
#  'bagel': 654,
#  'chanc': 655,
#  'satisfi': 656,
#  'present': 657,
#  'neighborhood': 658,
#  'dark': 659,
#  'car': 660,
#  'accommod': 661,
#  'explain': 662,
#  'apolog': 663,
#  'margarita': 664,
#  'write': 665,
#  'tradit': 666,
#  'waffl': 667,
#  'smoke': 668,
#  'thin': 669,
#  'world': 670,
#  'melt': 671,
#  'pepperoni': 672,
#  'meet': 673,
#  'bag': 674,
#  'cost': 675,
#  'taken': 676,
#  'greasi': 677,
#  'pass': 678,
#  'oil': 679,
#  'spend': 680,
#  'compar': 681,
#  'provid': 682,
#  'chili': 683,
#  'buy': 684,
#  'slightli': 685,
#  'rush': 686,
#  'indian': 687,
#  'thick': 688,
#  'question': 689,
#  'gem': 690,
#  'asian': 691,
#  'box': 692,
#  'banana': 693,
#  'biscuit': 694,
#  'request': 695,
#  'healthi': 696,
#  'number': 697,
#  'al': 698,
#  'oyster': 699,
#  'calamari': 700,
#  'frequent': 701,
#  'floor': 702,
#  'continu': 703,
#  'realiz': 704,
#  'smell': 705,
#  'state': 706,
#  'dirti': 707,
#  'classic': 708,
#  'pastri': 709,
#  'pictur': 710,
#  'valu': 711,
#  'low': 712,
#  'falafel': 713,
#  'combo': 714,
#  'ahead': 715,
#  'simpli': 716,
#  '45': 717,
#  'stuf': 718,
#  'singl': 719,
#  'longer': 720,
#  'save': 721,
#  'creami': 722,
#  'sorri': 723,
#  'strip': 724,
#  'exactli': 725,
#  'idea': 726,
#  'touch': 727,
#  'lemon': 728,
#  'origin': 729,
#  'pad': 730,
#  'bathroom': 731,
#  'die': 732,
#  'juici': 733,
#  'word': 734,
#  'club': 735,
#  'cannot': 736,
#  'mine': 737,
#  'son': 738,
#  'middl': 739,
#  'mediocr': 740,
#  'summer': 741,
#  'knowledg': 742,
#  'tv': 743,
#  'hang': 744,
#  'cheesecak': 745,
#  'american': 746,
#  'suppos': 747,
#  'crisp': 748,
#  '25': 749,
#  'mom': 750,
#  'worker': 751,
#  'notch': 752,
#  'fairli': 753,
#  'ranch': 754,
#  'filet': 755,
#  'easili': 756,
#  'interior': 757,
#  'sort': 758,
#  'booth': 759,
#  'truli': 760,
#  'mostli': 761,
#  'chop': 762,
#  'hotel': 763,
#  'possibl': 764,
#  'upon': 765,
#  'celebr': 766,
#  'combin': 767,
#  'scallop': 768,
#  'curri': 769,
#  'cooki': 770,
#  'mess': 771,
#  'fix': 772,
#  'speak': 773,
#  'convers': 774,
#  'certainli': 775,
#  'remind': 776,
#  'view': 777,
#  'overpr': 778,
#  'cinnamon': 779,
#  'afternoon': 780,
#  'patron': 781,
#  'goe': 782,
#  'gotten': 783,
#  'anywher': 784,
#  'tuna': 785,
#  'doubl': 786,
#  'updat': 787,
#  'oliv': 788,
#  'figur': 789,
#  'avocado': 790,
#  'eye': 791,
#  'opinion': 792,
#  'honey': 793,
#  'slaw': 794,
#  'chose': 795,
#  'spinach': 796,
#  'within': 797,
#  'case': 798,
#  '00': 799,
#  'daughter': 800,
#  'outdoor': 801,
#  'monday': 802,
#  'textur': 803,
#  'smile': 804,
#  'easton': 805,
#  '11': 806,
#  'mash': 807,
#  'unless': 808,
#  'occas': 809,
#  'tortilla': 810,
#  'complain': 811,
#  'fair': 812,
#  'aw': 813,
#  'multipl': 814,
#  'answer': 815,
#  'whatev': 816,
#  'bare': 817,
#  'forgot': 818,
#  'relax': 819,
#  'drop': 820,
#  'pop': 821,
#  'fanci': 822,
#  'guest': 823,
#  'environ': 824,
#  'face': 825,
#  'polit': 826,
#  'sprout': 827,
#  'broth': 828,
#  'appear': 829,
#  'beat': 830,
#  'forget': 831,
#  'beyond': 832,
#  'matter': 833,
#  'avoid': 834,
#  'hold': 835,
#  'cozi': 836,
#  'boy': 837,
#  'delight': 838,
#  'hate': 839,
#  'young': 840,
#  'book': 841,
#  'crazi': 842,
#  'clearli': 843,
#  'kick': 844,
#  'alon': 845,
#  'dumpl': 846,
#  'weird': 847,
#  'craft': 848,
#  'rich': 849,
#  'non': 850,
#  'strong': 851,
#  'sad': 852,
#  'smaller': 853,
#  'follow': 854,
#  '40': 855,
#  'becom': 856,
#  'wast': 857,
#  'gravi': 858,
#  'tini': 859,
#  'corner': 860,
#  'clear': 861,
#  'crunchi': 862,
#  'correct': 863,
#  'tap': 864,
#  'draft': 865,
#  'tuesday': 866,
#  'dollar': 867,
#  'host': 868,
#  'commun': 869,
#  'somewher': 870,
#  'mediterranean': 871,
#  'sugar': 872,
#  'tofu': 873,
#  'kinda': 874,
#  'ramen': 875,
#  'carrot': 876,
#  'villag': 877,
#  'concept': 878,
#  'load': 879,
#  'ring': 880,
#  'buck': 881,
#  'brew': 882,
#  'road': 883,
#  'pud': 884,
#  'blue': 885,
#  'shot': 886,
#  'true': 887,
#  'w': 888,
#  'lol': 889,
#  'fruit': 890,
#  'girlfriend': 891,
#  'takeout': 892,
#  'turkey': 893,
#  'spring': 894,
#  'juic': 895,
#  'mistak': 896,
#  'fabul': 897,
#  'chair': 898,
#  'phenomen': 899,
#  'none': 900,
#  'post': 901,
#  'obvious': 902,
#  'frozen': 903,
#  'coupon': 904,
#  'pour': 905,
#  'leftov': 906,
#  'heavi': 907,
#  'pm': 908,
#  'raw': 909,
#  'fire': 910,
#  'profession': 911,
#  'step': 912,
#  'otherwis': 913,
#  'school': 914,
#  'appl': 915,
#  'fall': 916,
#  'mall': 917,
#  'ball': 918,
#  'round': 919,
#  'plain': 920,
#  'agre': 921,
#  'hidden': 922,
#  'dog': 923,
#  'ridicul': 924,
#  'spent': 925,
#  'conveni': 926,
#  'similar': 927,
#  'appar': 928,
#  'folk': 929,
#  'peanut': 930,
#  'quesadilla': 931,
#  'sport': 932,
#  'lucki': 933,
#  'soggi': 934,
#  'inform': 935,
#  'opt': 936,
#  'balanc': 937,
#  'afford': 938,
#  'tough': 939,
#  'parmesan': 940,
#  'allow': 941,
#  'perhap': 942,
#  'forev': 943,
#  'despit': 944,
#  'mcdonald': 945,
#  'per': 946,
#  'futur': 947,
#  'heart': 948,
#  'product': 949,
#  'confus': 950,
#  'platter': 951,
#  'buffalo': 952,
#  'difficult': 953,
#  'bottom': 954,
#  'popular': 955,
#  'separ': 956,
#  'rave': 957,
#  'attitud': 958,
#  '100': 959,
#  'neg': 960,
#  'met': 961,
#  'posit': 962,
#  'contain': 963,
#  'la': 964,
#  'northstar': 965,
#  'soda': 966,
#  'version': 967,
#  'hash': 968,
#  'bone': 969,
#  'handl': 970,
#  'chorizo': 971,
#  'break': 972,
#  'nearli': 973,
#  'effici': 974,
#  'nacho': 975,
#  'comment': 976,
#  'pot': 977,
#  'burnt': 978,
#  'rock': 979,
#  'imagin': 980,
#  'overli': 981,
#  'mood': 982,
#  'modern': 983,
#  'brussel': 984,
#  'queso': 985,
#  'german': 986,
#  'awhil': 987,
#  'broccoli': 988,
#  'pair': 989,
#  'sister': 990,
#  'improv': 991,
#  'nearbi': 992,
#  'giant': 993,
#  'groceri': 994,
#  'cuisin': 995,
#  'annoy': 996,
#  'alcohol': 997,
#  'member': 998,
#  'pretzel': 999,
#  'bell': 1000,
#  ...}

# %%
# Creates the sequences from our tokenizer, based on the indices from the word_index
train_sequences = tokenizer.texts_to_sequences(X_train)

# %%
X_train.values[0]
# Out:
# 'well final got around tri place like got meatloaf melt fri ok wish would got someth els honest want get anyth adventur diner first time meatloaf fri flat top grill end dri result fri averag hot tea great although littl thing impress special day got bite chicken homemad noodl veggi still littl crunchi dish well done usual like sort thing friend pasta must pretti good say jack shit gone kind picki eater oh one thing legal tender challeng friend cash'

# %%
train_sequences[0]  # This sequence has 24 words
# Out:
# [29,
#  260,
#  20,
#  109,
#  13,
#  3,
#  7,
#  20,
#  1515,
#  671,
#  36,
#  227,
#  330,
#  14,
#  20,
#  118,
#  245,
#  1227,
#  37,
#  8,
#  234,
#  1531,
#  580,
#  45,
#  6,
#  1515,
#  36,
#  1170,
#  76,
#  314,
#  190,
#  357,
#  1622,
#  36,
#  426,
#  93,
#  276,
#  5,
#  416,
#  42,
#  67,
#  267,
#  122,
#  90,
#  20,
#  324,
#  16,
#  638,
#  480,
#  299,
#  99,
#  42,
#  862,
#  89,
#  29,
#  316,
#  188,
#  7,
#  758,
#  67,
#  74,
#  403,
#  307,
#  53,
#  2,
#  68,
#  1796,
#  1807,
#  597,
#  195,
#  1364,
#  1344,
#  337,
#  11,
#  67,
#  4879,
#  427,
#  1787,
#  74,
#  1052]

# %%
len(train_sequences[0])
# Out:
# 80

# %%
# Now adding padding
from tensorflow.keras.preprocessing.sequence import pad_sequences 

train_padded = pad_sequences(
    train_sequences, maxlen=max_length, padding='post', truncating='post'
)

# %%
train_padded[0]
# Out:
# array([  29,  260,   20,  109,   13,    3,    7,   20, 1515,  671,   36,
#         227,  330,   14,   20,  118,  245, 1227,   37,    8,  234, 1531,
#         580,   45,    6, 1515,   36, 1170,   76,  314,  190,  357, 1622,
#          36,  426,   93,  276,    5,  416,   42,   67,  267,  122,   90,
#          20,  324,   16,  638,  480,  299], dtype=int32)

# %%
# Creates the test dataset sequences and padding
test_sequences = tokenizer.texts_to_sequences(X_test)
test_padded = pad_sequences(
    test_sequences, maxlen=max_length, padding='post', truncating='post'
)

# %%
print(X_train.values[0])
print(train_sequences[0])
# Out:
# well final got around tri place like got meatloaf melt fri ok wish would got someth els honest want get anyth adventur diner first time meatloaf fri flat top grill end dri result fri averag hot tea great although littl thing impress special day got bite chicken homemad noodl veggi still littl crunchi dish well done usual like sort thing friend pasta must pretti good say jack shit gone kind picki eater oh one thing legal tender challeng friend cash
# [29, 260, 20, 109, 13, 3, 7, 20, 1515, 671, 36, 227, 330, 14, 20, 118, 245, 1227, 37, 8, 234, 1531, 580, 45, 6, 1515, 36, 1170, 76, 314, 190, 357, 1622, 36, 426, 93, 276, 5, 416, 42, 67, 267, 122, 90, 20, 324, 16, 638, 480, 299, 99, 42, 862, 89, 29, 316, 188, 7, 758, 67, 74, 403, 307, 53, 2, 68, 1796, 1807, 597, 195, 1364, 1344, 337, 11, 67, 4879, 427, 1787, 74, 1052]

# %%
# Checks to make sure that you can decode in reverse 
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

decode(train_sequences[0])
# Out:
# 'well final got around tri place like got meatloaf melt fri ok wish would got someth els honest want get anyth adventur diner first time meatloaf fri flat top grill end dri result fri averag hot tea great although littl thing impress special day got bite chicken homemad noodl veggi still littl crunchi dish well done usual like sort thing friend pasta must pretti good say jack shit gone kind picki eater oh one thing legal tender challeng friend cash'

# %%
# Checks the shape of the train and the shape of the test
print(f'Shape of train {train_padded.shape}')
print(f'Shape of test {test_padded.shape}')
# Out:
# Shape of train (48650, 50)
# Shape of test (16217, 50)

# %% [markdown]
# ### Set up the Network topology
#
# * We could've used One Hot Encoding (OHE) to convert these indices into vectors of 0s an 1s, but this would increase the dimensionality of our features
#
# **Instead...**
# * The Embedding layer - maps each word to a vector of a fixed size with real value elements...
# * In contrast to One Hot Encoding, we can use finite size vector to represent an infinite number of real numbers.
# * We're going to use dimensionality of this embedding layer (32) and the input length will be the max length

# %%
# Sets up network topology 
model = Sequential()

model.add(Embedding(num_words, 32, input_length=max_length))

# LSTM layer
model.add(LSTM(24))

# Dense hidden layers
model.add(Dense(64, activation='relu', kernel_regularizer=l2(.001)))
model.add(Dropout(0.5))

model.add(Dense(8, activation='relu', kernel_regularizer=l2(.001)))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(4, activation='softmax'))

optimizer = Adam(lr=3e-4)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 50, 32)            900864
# _________________________________________________________________
# lstm (LSTM)                  (None, 24)                5472
# _________________________________________________________________
# dense (Dense)                (None, 64)                1600
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 36
# =================================================================
# Total params: 908,492
# Trainable params: 908,492
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history = model.fit(
    train_padded, y_train, epochs=25, batch_size=256, 
    validation_data=(test_padded, y_test)
)
# Out:
# Epoch 1/25
# 191/191 [==============================] - 28s 125ms/step - loss: 1.4157 - acc: 0.3215 - val_loss: 1.3893 - val_acc: 0.3287
# Epoch 2/25
# 191/191 [==============================] - 24s 126ms/step - loss: 1.3769 - acc: 0.3333 - val_loss: 1.2832 - val_acc: 0.4463
# Epoch 3/25
# 191/191 [==============================] - 22s 116ms/step - loss: 1.2630 - acc: 0.4311 - val_loss: 1.1641 - val_acc: 0.4641
# Epoch 4/25
# 191/191 [==============================] - 23s 121ms/step - loss: 1.1705 - acc: 0.4761 - val_loss: 1.1314 - val_acc: 0.4797
# Epoch 5/25
# 191/191 [==============================] - 24s 124ms/step - loss: 1.1150 - acc: 0.4980 - val_loss: 1.1196 - val_acc: 0.4908
# Epoch 6/25
# 191/191 [==============================] - 23s 122ms/step - loss: 1.0789 - acc: 0.5129 - val_loss: 1.1123 - val_acc: 0.4977
# Epoch 7/25
# 191/191 [==============================] - 24s 126ms/step - loss: 1.0605 - acc: 0.5176 - val_loss: 1.1251 - val_acc: 0.4995
# Epoch 8/25
# 191/191 [==============================] - 24s 126ms/step - loss: 1.0391 - acc: 0.5355 - val_loss: 1.1372 - val_acc: 0.5003
# Epoch 9/25
# 191/191 [==============================] - 23s 122ms/step - loss: 1.0126 - acc: 0.5456 - val_loss: 1.1641 - val_acc: 0.5024
# Epoch 10/25
# 191/191 [==============================] - 23s 123ms/step - loss: 0.9963 - acc: 0.5524 - val_loss: 1.1676 - val_acc: 0.5041
# Epoch 11/25
# 191/191 [==============================] - 23s 123ms/step - loss: 0.9762 - acc: 0.5632 - val_loss: 1.1961 - val_acc: 0.4982
# Epoch 12/25
# 191/191 [==============================] - 23s 119ms/step - loss: 0.9601 - acc: 0.5751 - val_loss: 1.2346 - val_acc: 0.5132
# Epoch 13/25
# 191/191 [==============================] - 24s 124ms/step - loss: 0.9445 - acc: 0.5796 - val_loss: 1.2271 - val_acc: 0.5032
# Epoch 14/25
# 191/191 [==============================] - 23s 119ms/step - loss: 0.9281 - acc: 0.5883 - val_loss: 1.2434 - val_acc: 0.4995
# Epoch 15/25
# 191/191 [==============================] - 24s 125ms/step - loss: 0.9145 - acc: 0.5971 - val_loss: 1.3856 - val_acc: 0.5129
# Epoch 16/25
# 191/191 [==============================] - 24s 124ms/step - loss: 0.9063 - acc: 0.5990 - val_loss: 1.2751 - val_acc: 0.4973
# Epoch 17/25
# 191/191 [==============================] - 25s 133ms/step - loss: 0.9047 - acc: 0.5992 - val_loss: 1.3770 - val_acc: 0.5103
# Epoch 18/25
# 191/191 [==============================] - 31s 161ms/step - loss: 0.8892 - acc: 0.6068 - val_loss: 1.4073 - val_acc: 0.5105
# Epoch 19/25
# 191/191 [==============================] - 30s 157ms/step - loss: 0.8721 - acc: 0.6116 - val_loss: 1.4510 - val_acc: 0.5103
# Epoch 20/25
# 191/191 [==============================] - 24s 124ms/step - loss: 0.8625 - acc: 0.6187 - val_loss: 1.4569 - val_acc: 0.5125
# Epoch 21/25
# 191/191 [==============================] - 24s 126ms/step - loss: 0.8615 - acc: 0.6187 - val_loss: 1.4003 - val_acc: 0.5007
# Epoch 22/25
# 191/191 [==============================] - 24s 123ms/step - loss: 0.8611 - acc: 0.6198 - val_loss: 1.4995 - val_acc: 0.5076
# Epoch 23/25
# 191/191 [==============================] - 25s 130ms/step - loss: 0.8543 - acc: 0.6216 - val_loss: 1.5342 - val_acc: 0.5079
# Epoch 24/25
# 191/191 [==============================] - 24s 126ms/step - loss: 0.8513 - acc: 0.6257 - val_loss: 1.4171 - val_acc: 0.4987
# Epoch 25/25
# 191/191 [==============================] - 31s 164ms/step - loss: 0.8367 - acc: 0.6278 - val_loss: 1.5800 - val_acc: 0.5090

# %%
df['amb_target'].value_counts(normalize=True)
# Out:
# 1    0.328703
# 3    0.279911
# 2    0.207394
# 0    0.183992
# Name: amb_target, dtype: float64
