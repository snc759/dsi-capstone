# %% [markdown]
# # Modeling a Multi-Class Prediction using TensorFlow LSTM With More Balanced Classes

# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import time

# standard sklearn imports
from sklearn.datasets import make_classification, make_regression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV

# tensorflow imports for Neural Networks
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D, MaxPooling2D, GRU, LSTM, Embedding
from tensorflow.keras.initializers import Constant
from tensorflow.keras.optimizers import Adam

# Import regularizers
from tensorflow.keras.regularizers import l2
# Import Dropout
from tensorflow.keras.layers import Dropout
# Import Early Stopping
from tensorflow.keras.callbacks import EarlyStopping

from tensorflow.keras.utils import to_categorical, plot_model

# CNN imports 
import os
from tensorflow.keras.preprocessing.image import img_to_array, load_img

# GridSearch imports 
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

# RNN imports 
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator




# imports for reports on classification
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, accuracy_score

plt.style.use(style='seaborn')
# %matplotlib inline

# %%
df = pd.read_csv('../../Data/reviews_stemmed_balanced.csv')
df.head()
# Out:
#               business_id                       name               review_id  \
# 0  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  wve8w6gIuPpCfo5J--AHjg
# 1  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  5rFuHGGbimVxPHxgM0sNSA
# 2  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  2iD3Rdbw0DUzjZSqBq3hXQ
# 3  0lCiLKpjrinltPFbBby4sw  The Great Wall Restaurant  e61y5ZlNwg04mAGtcD3vbQ
# 4  kZFTi8FKjs30EuzurZ3v3g             Donerick's Pub  38lN2ONaypsfBDLwhGxcSg
#
#    review_stars                                               text  \
# 0             3  The menu sounded promising, with over fifty di...
# 1             3  This wasn't the worst Chinese food but it wasn...
# 2             1  I have been coming to this restaurant for over...
# 3             5  My husband and I love this place.\nGreat price...
# 4             5  Great place for beverages with your friends wh...
#
#    amb_casual  amb_classy  amb_target  text_length  \
# 0         0.0         0.0           0          121
# 1         0.0         0.0           0           78
# 2         0.0         0.0           0           52
# 3         0.0         0.0           0           23
# 4         0.0         0.0           0           61
#
#                                           clean_text  clean_text_length  \
# 0  menu sounded promising fifty different dishes ...                 68
# 1  wasn' worst chinese food wasn' best egg foo yo...                 41
# 2  coming restaurant 20 years purchased shrimp fr...                 27
# 3  husband love place great price lot food make s...                 13
# 4  great place beverages friends watch game lots ...                 43
#
#                                      clean_text_stem  clean_text_stem_length
# 0  menu sound promis fifti differ dish differ sty...                      66
# 1  worst chines food best egg foo young dri overc...                      39
# 2  come restaur 20 year purchas shrimp fri rice g...                      26
# 3  husband love place great price lot food make s...                      12
# 4  great place beverag friend watch game lot tv g...                      43

# %% [markdown]
# ## 1) Modeling with stemmed text

# %%
# Sets up X and y
X = df['clean_text_stem']
y = df['amb_target']

# %%
# One-hot encoding for the categorical y response variable 
y = to_categorical(y)

# %%
# Splits the data into training and test sets from sample
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    stratify=y, 
                                                    random_state=42)

# %%
X_train
# Out:
# 8210     look breakfast place town tri stumbl upon mcca...
# 12563    love mohawk atmospher food outstand bad thing ...
# 55374    tri sever chines place powel worth mention twi...
# 34856    boyfriend stop dinner first night drive across...
# 17500    stop ice cream treat dinner main street love i...
#                                ...
# 47234    great food comfort atmospher food great gorgeo...
# 49006    bang buck price got awesom mediterrenean food ...
# 62754    bibibop nice wide select fresh ingredi broad s...
# 25465    best servic small oper much staff partli accou...
# 26940    chicken avocado sandwich favorit mine none foo...
# Name: clean_text_stem, Length: 48650, dtype: object

# %% [markdown]
# ### Basic NLP

# %%
# import the Counter function
from collections import Counter

# import the tokenizer from keras preprocessing 
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Creates a function that counts unique words
def counter_word(text):
    count = Counter()
    for doc in text.values:
        for word in doc.split():
            count[word] += 1
    return count

# %%
X_train
# Out:
# 8210     look breakfast place town tri stumbl upon mcca...
# 12563    love mohawk atmospher food outstand bad thing ...
# 55374    tri sever chines place powel worth mention twi...
# 34856    boyfriend stop dinner first night drive across...
# 17500    stop ice cream treat dinner main street love i...
#                                ...
# 47234    great food comfort atmospher food great gorgeo...
# 49006    bang buck price got awesom mediterrenean food ...
# 62754    bibibop nice wide select fresh ingredi broad s...
# 25465    best servic small oper much staff partli accou...
# 26940    chicken avocado sandwich favorit mine none foo...
# Name: clean_text_stem, Length: 48650, dtype: object

# %%
X_train.values[0]
# Out:
# 'look breakfast place town tri stumbl upon mccarthi smaller size resteraunt think make due space busi saturday afternoon expect got tabl pretti quickli order skillet scrambler pancak signific got egg benedict skillet good howev call skillet like scrambl egg minc meat side scallop potato potato melt mouth good egg cook excel toast brought delici pancak superb size plate nice circumfer also thicker pancak great tast great said egg benedict alright egg slightli undercook hollandais alright much flavor also would like ham thicker piec ham instead shave use overal price reason food good servic nice throughout visit definit go back'

# %%
# Counts the number of times a unique word appears
counter = counter_word(X_train)

# %%
# Finds the length or the number of unique words
len(counter)
# Out:
# 28152

# %%
counter
# Out:
# Counter({'look': 7820,
#          'breakfast': 3070,
#          'place': 27596,
#          'town': 2618,
#          'tri': 14430,
#          'stumbl': 176,
#          'upon': 665,
#          'mccarthi': 4,
#          'smaller': 545,
#          'size': 2286,
#          'resteraunt': 6,
#          'think': 5441,
#          'make': 8633,
#          'due': 936,
#          'space': 1567,
#          'busi': 4994,
#          'saturday': 1543,
#          'afternoon': 637,
#          'expect': 3589,
#          'got': 11134,
#          'tabl': 8251,
#          'pretti': 6886,
#          'quickli': 1435,
#          'order': 25399,
#          'skillet': 205,
#          'scrambler': 45,
#          'pancak': 832,
#          'signific': 64,
#          'egg': 3230,
#          'benedict': 149,
#          'good': 30628,
#          'howev': 2895,
#          'call': 3175,
#          'like': 19968,
#          'scrambl': 181,
#          'minc': 25,
#          'meat': 4288,
#          'side': 5949,
#          'scallop': 614,
#          'potato': 3020,
#          'melt': 777,
#          'mouth': 845,
#          'cook': 4128,
#          'excel': 3948,
#          'toast': 1237,
#          'brought': 1802,
#          'delici': 9433,
#          'superb': 281,
#          'plate': 2530,
#          'nice': 9437,
#          'circumfer': 5,
#          'also': 11362,
#          'thicker': 108,
#          'great': 23644,
#          'tast': 7742,
#          'said': 4840,
#          'alright': 288,
#          'slightli': 722,
#          'undercook': 242,
#          'hollandais': 62,
#          'much': 6554,
#          'flavor': 7298,
#          'would': 13154,
#          'ham': 368,
#          'piec': 1634,
#          'instead': 1613,
#          'shave': 89,
#          'use': 3771,
#          'overal': 3048,
#          'price': 7921,
#          'reason': 2964,
#          'food': 36271,
#          'servic': 17258,
#          'throughout': 366,
#          'visit': 5499,
#          'definit': 7296,
#          'go': 18641,
#          'back': 14505,
#          'love': 12721,
#          'mohawk': 163,
#          'atmospher': 4285,
#          'outstand': 911,
#          'bad': 4013,
#          'thing': 6192,
#          'say': 5886,
#          'park': 3217,
#          'suck': 402,
#          'must': 1827,
#          'restaur': 12531,
#          'glad': 1145,
#          'sever': 2050,
#          'chines': 1731,
#          'powel': 193,
#          'worth': 3593,
#          'mention': 1155,
#          'twice': 1092,
#          'found': 2193,
#          'quit': 2449,
#          'tasti': 3472,
#          'favorit': 5367,
#          'dish': 5092,
#          'sesam': 263,
#          'chicken': 12804,
#          'sweet': 3877,
#          'sour': 800,
#          'pork': 2367,
#          'start': 3084,
#          'deliveri': 1122,
#          'best': 9072,
#          'boyfriend': 984,
#          'stop': 3641,
#          'dinner': 5477,
#          'first': 7479,
#          'night': 6148,
#          'drive': 2226,
#          'across': 860,
#          'countri': 370,
#          'california': 255,
#          'made': 6351,
#          'us': 9305,
#          'vegan': 912,
#          'everyth': 5320,
#          'soo': 57,
#          'amaz': 6792,
#          'convert': 41,
#          'eater': 281,
#          'instantli': 78,
#          'push': 241,
#          'vegetarian': 1107,
#          'still': 4869,
#          'crave': 901,
#          'ice': 2096,
#          'cream': 2069,
#          'treat': 1088,
#          'main': 1081,
#          'street': 1640,
#          'option': 4062,
#          'even': 9624,
#          'sandwich': 5916,
#          'knew': 787,
#          'appreci': 888,
#          'larg': 2955,
#          'plexiglass': 10,
#          'near': 910,
#          'regist': 410,
#          'keep': 1939,
#          'safe': 301,
#          'outdoor': 628,
#          'pick': 2288,
#          'prefer': 893,
#          'get': 18692,
#          'day': 5116,
#          'come': 10176,
#          '8': 1417,
#          'scoop': 199,
#          'challegeng': 1,
#          'went': 6735,
#          'lunch': 5075,
#          'chip': 2150,
#          'salsa': 1214,
#          'corn': 1071,
#          'enchilada': 195,
#          'small': 4314,
#          'fill': 2104,
#          'servant': 4,
#          'friendli': 6887,
#          'effici': 438,
#          'shorti': 13,
#          'expand': 160,
#          'delawar': 107,
#          'enjoy': 5487,
#          'carryout': 258,
#          'week': 2567,
#          'pizza': 9256,
#          'wing': 2723,
#          'sub': 1292,
#          'last': 3779,
#          'extend': 69,
#          'famili': 2672,
#          'two': 5495,
#          'extra': 1848,
#          'italian': 1458,
#          'promis': 277,
#          '20': 1863,
#          'min': 943,
#          'readi': 1277,
#          'time': 21022,
#          'home': 3174,
#          'hot': 5075,
#          'fresh': 5927,
#          'staff': 7216,
#          'alway': 8686,
#          'greet': 1088,
#          'arriv': 2240,
#          'pickup': 259,
#          'sit': 3011,
#          'highli': 2151,
#          'recommend': 6190,
#          'mvp': 4,
#          'suprem': 94,
#          'pepperoni': 765,
#          'rel': 280,
#          'thin': 772,
#          'wafer': 18,
#          'new': 4511,
#          'york': 310,
#          'style': 1710,
#          'cover': 785,
#          'chees': 7627,
#          'top': 5649,
#          '8in': 1,
#          'full': 2771,
#          'insid': 2719,
#          'cool': 1931,
#          'bar': 8526,
#          'area': 4611,
#          'seat': 5149,
#          '12': 880,
#          '15': 1674,
#          'patio': 2392,
#          'bartend': 2032,
#          'plenti': 1657,
#          'front': 1660,
#          'plaza': 106,
#          'udf': 9,
#          'opposit': 97,
#          'end': 2840,
#          'thank': 1841,
#          'golden': 159,
#          'china': 133,
#          'one': 16135,
#          'daughter': 611,
#          'takeout': 532,
#          'hilliard': 284,
#          'pleas': 1459,
#          'choic': 2181,
#          'qualiti': 3570,
#          'high': 2776,
#          'profil': 88,
#          'portion': 3207,
#          'point': 2187,
#          'agreeabl': 3,
#          'kung': 94,
#          'pao': 74,
#          'roll': 3489,
#          'crab': 1253,
#          'rangoon': 368,
#          'steam': 384,
#          'dumpl': 587,
#          'stood': 325,
#          'rest': 846,
#          'textur': 604,
#          'amount': 1608,
#          'truli': 680,
#          'columbu': 6799,
#          'find': 3635,
#          'shrimp': 2496,
#          'frozen': 512,
#          'eddi': 121,
#          'bland': 1076,
#          'steak': 3142,
#          'bourbon': 399,
#          'ribey': 185,
#          'fatti': 154,
#          'cut': 1238,
#          'correctli': 168,
#          'cake': 1490,
#          'clearli': 547,
#          'well': 9285,
#          'without': 2232,
#          'drink': 9928,
#          'total': 1416,
#          'bill': 1104,
#          '95': 187,
#          '1': 2932,
#          'person': 2738,
#          'anyth': 2405,
#          'water': 1960,
#          'let': 2469,
#          'especi': 1934,
#          'attract': 167,
#          'obvious': 503,
#          'tea': 2015,
#          'okonomiyaki': 5,
#          'though': 4079,
#          'authent': 1323,
#          'need': 4423,
#          'could': 6575,
#          'bring': 1899,
#          'young': 559,
#          'children': 243,
#          'meet': 743,
#          'state': 711,
#          'complet': 1238,
#          'incorrect': 119,
#          'item': 2736,
#          'left': 2393,
#          'hostess': 874,
#          'combo': 724,
#          'packag': 184,
#          'save': 721,
#          'money': 1440,
#          'polit': 589,
#          'counter': 1316,
#          'explain': 766,
#          'issu': 1210,
#          'ask': 6502,
#          'receipt': 241,
#          'never': 6772,
#          'gave': 1870,
#          'care': 1937,
#          '2': 5060,
#          'differ': 3440,
#          'employe': 1563,
#          'manag': 3582,
#          'forth': 81,
#          'print': 91,
#          'origin': 676,
#          'agre': 451,
#          'void': 31,
#          'recharg': 4,
#          'offer': 3238,
#          'consider': 95,
#          'chang': 1676,
#          'cost': 777,
#          'help': 2977,
#          'group': 1991,
#          'train': 343,
#          'custom': 3858,
#          'sure': 4820,
#          'job': 1064,
#          'experi': 6581,
#          'particular': 399,
#          'anyon': 1237,
#          'unhappi': 63,
#          'fun': 2356,
#          'kid': 1961,
#          'neighborhood': 791,
#          'al': 725,
#          'happi': 4264,
#          'hour': 4987,
#          'awesom': 3394,
#          'limit': 783,
#          'menu': 9785,
#          'eclect': 137,
#          'mix': 1516,
#          'crowd': 1696,
#          'not': 1,
#          'welcom': 1013,
#          'folk': 496,
#          'bigger': 350,
#          'although': 1387,
#          'wait': 9487,
#          'second': 1820,
#          'walk': 3582,
#          'friend': 5828,
#          'impress': 2110,
#          'styliz': 4,
#          'ikea': 16,
#          'three': 1994,
#          'star': 4769,
#          'show': 1435,
#          'carrot': 515,
#          'enough': 3293,
#          'everi': 4063,
#          'im': 205,
#          'disappoint': 4331,
#          'mayb': 2541,
#          'littl': 7905,
#          'pricier': 116,
#          'truck': 841,
#          'consist': 1353,
#          'serv': 4973,
#          'taco': 4245,
#          '75': 193,
#          'valu': 699,
#          'noth': 2897,
#          'fanci': 562,
#          'stuff': 970,
#          'quesadilla': 466,
#          'torta': 199,
#          'jarito': 1,
#          'soda': 429,
#          'year': 3640,
#          'greek': 1130,
#          'fri': 8296,
#          'realli': 12947,
#          'overlook': 137,
#          'tender': 1351,
#          'brussel': 433,
#          'sprout': 576,
#          'yum': 974,
#          'cheeseburg': 301,
#          'son': 665,
#          'bacon': 2062,
#          'stir': 99,
#          'burger': 4740,
#          'greasi': 767,
#          'wrap': 1055,
#          'transluc': 4,
#          '3': 4089,
#          'tablespoon': 19,
#          'mayo': 375,
#          'ketchup': 237,
#          'mixtur': 101,
#          'drip': 122,
#          'worst': 1225,
#          'ever': 4952,
#          'wendi': 269,
#          'gener': 1842,
#          'cannot': 647,
#          'brag': 50,
#          'believ': 1087,
#          'sushi': 2068,
#          'mean': 1399,
#          'clean': 2756,
#          'classi': 320,
#          'absolut': 2495,
#          'impecc': 158,
#          'wish': 1663,
#          'cincinnati': 173,
#          'seem': 4382,
#          'imposs': 159,
#          'figur': 613,
#          'lot': 5415,
#          'behind': 957,
#          'build': 917,
#          'sinc': 3969,
#          'head': 1045,
#          'give': 5037,
#          'spot': 3457,
#          'anoth': 3848,
#          'chanc': 782,
#          'around': 4436,
#          'better': 5636,
#          'moment': 308,
#          'invit': 376,
#          'harder': 43,
#          'leav': 1877,
#          'comfort': 1107,
#          'mind': 1102,
#          'bump': 111,
#          'music': 1331,
#          'sound': 781,
#          'blare': 24,
#          'took': 3814,
#          'eye': 629,
#          'candi': 196,
#          'way': 5183,
#          'view': 627,
#          'form': 195,
#          'previou': 332,
#          'review': 4138,
#          'chore': 14,
#          'forward': 916,
#          'next': 3837,
#          'cafe': 887,
#          'kind': 2862,
#          'averag': 1321,
#          'strip': 702,
#          'mall': 492,
#          'cours': 1554,
#          'interior': 655,
#          'mani': 3972,
#          'peopl': 6161,
#          'may': 1701,
#          'feel': 4008,
#          'actual': 2685,
#          'stay': 1187,
#          'fine': 1561,
#          'dine': 3305,
#          'liquor': 261,
#          'japanes': 232,
#          'hunan': 73,
#          'bean': 1803,
#          'curd': 145,
#          '9': 961,
#          'regular': 1596,
#          'proud': 74,
#          'room': 2152,
#          'big': 3126,
#          'join': 162,
#          'yelp': 1159,
#          'goremad': 16,
#          'block': 358,
#          'pie': 1124,
#          'wise': 225,
#          'far': 1884,
#          'beat': 567,
#          'harvest': 90,
#          'easili': 665,
#          'soul': 165,
#          'confid': 77,
#          'dough': 298,
#          'pauli': 4,
#          'gee': 23,
#          'yet': 1494,
#          'admittedli': 52,
#          'partisan': 1,
#          'opinion': 630,
#          'warm': 2040,
#          'unfussi': 1,
#          'woodwork': 8,
#          'lovingli': 8,
#          'handmad': 48,
#          'ingredi': 1445,
#          'local': 2300,
#          'want': 8200,
#          'chanterel': 2,
#          'arugula': 148,
#          'cardamom': 8,
#          'tulsi': 1,
#          'forag': 3,
#          'sown': 1,
#          'togeth': 1031,
#          'earth': 155,
#          'godsend': 6,
#          'pro': 234,
#          'trendi': 308,
#          'decor': 1829,
#          'check': 3807,
#          'book': 562,
#          'write': 780,
#          'thought': 2481,
#          'okay': 1518,
#          'stuf': 667,
#          'ravioli': 240,
#          'lack': 1175,
#          'husband': 2790,
#          'con': 237,
#          'close': 2559,
#          'awkward': 198,
#          'bc': 196,
#          'hear': 799,
#          'convers': 640,
#          'right': 4828,
#          'glass': 1433,
#          'wine': 3249,
#          'notic': 1057,
#          'creativ': 338,
#          'blend': 302,
#          'classic': 670,
#          'adventur': 224,
#          'craft': 552,
#          'cocktail': 2243,
#          'often': 1463,
#          'spirit': 127,
#          'gem': 722,
#          'nyc': 170,
#          'live': 2433,
#          'bagel': 763,
#          'wet': 134,
#          'nap': 38,
#          'hershey': 14,
#          'kiss': 44,
#          'excit': 1159,
#          'surpris': 1592,
#          'kill': 213,
#          'guy': 1830,
#          'locat': 6320,
#          'black': 948,
#          'burrito': 1227,
#          'nasti': 244,
#          'laugh': 227,
#          'luck': 252,
#          'lol': 506,
#          'fast': 2686,
#          'bell': 405,
#          'grape': 151,
#          'put': 2460,
#          'facehol': 1,
#          'mujadara': 11,
#          'salad': 6944,
#          'lettuc': 901,
#          'lentil': 227,
#          'rice': 3122,
#          'weird': 561,
#          'pour': 507,
#          'hous': 2474,
#          'dress': 1383,
#          'tie': 94,
#          'perfectli': 1811,
#          'guess': 1054,
#          'someth': 4177,
#          'jimmi': 80,
#          'john': 188,
#          'wife': 2155,
#          'spring': 512,
#          'sick': 261,
#          'subway': 136,
#          'joint': 796,
#          'argu': 142,
#          'eat': 7976,
#          'hand': 1999,
#          'seek': 84,
#          'question': 736,
#          'shop': 1511,
#          'certain': 295,
#          'protocol': 30,
#          'handl': 433,
#          'driven': 104,
#          'stick': 853,
#          'suppos': 662,
#          'will': 346,
#          'strong': 531,
#          'ie': 27,
#          'someon': 1718,
#          'girlfriend': 507,
#          'mine': 692,
#          'arrang': 75,
#          'hang': 637,
#          'derbi': 11,
#          'flip': 215,
#          'hope': 1795,
#          'awhil': 426,
#          'mediterranean': 544,
#          'sunset': 30,
#          'holi': 356,
#          'cow': 80,
#          'calamari': 711,
#          'divin': 149,
#          'kabob': 150,
#          'share': 1695,
#          'pleasantli': 375,
#          'event': 840,
#          'oppos': 93,
#          'self': 303,
#          'veggi': 1906,
#          'super': 3517,
#          'jay': 58,
#          'posit': 435,
#          'know': 5341,
#          'rememb': 1216,
#          'name': 1690,
#          'normal': 1072,
#          '5': 4851,
#          'firebird': 95,
#          'buy': 761,
#          'joe': 249,
#          'tommi': 41,
#          'bought': 328,
#          '30th': 25,
#          'slice': 1386,
#          'realiz': 696,
#          'accustom': 38,
#          'spoke': 203,
#          'owner': 2010,
#          'less': 1539,
#          'laudatori': 1,
#          'told': 2945,
#          'return': 2403,
#          'per': 438,
#          'instruct': 87,
#          'receiv': 1395,
#          'replac': 333,
#          'prepar': 1534,
#          'speak': 639,
#          'frown': 14,
#          'frighten': 7,
#          'angrili': 13,
#          'manner': 164,
#          'encount': 145,
#          'unprofession': 143,
#          'extrem': 1511,
#          'unnerv': 1,
#          'unspeak': 3,
#          'race': 82,
#          'desir': 281,
#          'trash': 201,
#          'vow': 19,
#          'wrong': 1911,
#          'sorri': 685,
#          'inconveni': 120,
#          'confus': 449,
#          'similar': 472,
#          'asian': 710,
#          'inspir': 153,
#          'lemongrass': 229,
#          'phenomen': 519,
#          'waiter': 2025,
#          'chic': 76,
#          'elev': 270,
#          'tighten': 3,
#          'game': 1917,
#          'interest': 1097,
#          'beer': 4738,
#          'unfortun': 972,
#          'par': 347,
#          'bag': 763,
#          'least': 1851,
#          'shrivel': 10,
#          'bottom': 440,
#          'likewis': 18,
#          'entre': 1894,
#          'fail': 272,
#          'potenti': 179,
#          'came': 7304,
#          'breast': 320,
#          'bread': 4213,
#          'thick': 734,
#          'heavi': 481,
#          'curious': 4,
#          'restrict': 102,
#          'p': 234,
#          'standout': 72,
#          'signatur': 278,
#          'ale': 233,
#          'barleywin': 1,
#          'passabl': 28,
#          'whole': 1650,
#          'kept': 873,
#          'imagin': 427,
#          'gordon': 23,
#          'ramsay': 8,
#          'burst': 68,
#          'revamp': 22,
#          'whip': 215,
#          'kitchen': 1431,
#          'shape': 159,
#          'futur': 496,
#          'skip': 398,
#          'hr': 68,
#          '4th': 131,
#          'juli': 88,
#          'weekend': 1424,
#          'final': 2149,
#          'eagl': 370,
#          'tonight': 1033,
#          'short': 2240,
#          'north': 1963,
#          'born': 50,
#          'tennesse': 17,
#          'southern': 314,
#          'girl': 944,
#          'heart': 426,
#          'satisfi': 745,
#          '4': 3377,
#          'among': 228,
#          'four': 1000,
#          'collard': 162,
#          'spoon': 284,
#          'biscuit': 729,
#          'mac': 2089,
#          'n': 848,
#          'succotash': 32,
#          'cant': 184,
#          'modern': 431,
#          'bare': 619,
#          'move': 1499,
#          'summer': 657,
#          'u': 226,
#          'anybodi': 73,
#          '11': 591,
#          'cheap': 1069,
#          'warn': 282,
#          'shot': 565,
#          'tall': 116,
#          'pint': 212,
#          'plan': 926,
#          'accordingli': 57,
#          'brat': 42,
#          'dog': 476,
#          'wha': 5,
#          'ohio': 1284,
#          'theater': 184,
#          'pearl': 368,
#          'except': 1217,
#          'select': 3244,
#          'server': 5981,
#          'answer': 600,
#          'appet': 2995,
#          'jalapeno': 253,
#          'kick': 557,
#          'sausag': 1088,
#          'sampler': 269,
#          'ok': 2463,
#          'ladi': 833,
#          'split': 858,
#          'grit': 285,
#          'cinnamon': 641,
#          'role': 48,
#          'meal': 6995,
#          'rib': 1451,
#          'memor': 206,
#          'regularli': 181,
#          '7': 1372,
#          'crispi': 1621,
#          'honey': 623,
#          'red': 1618,
#          'sauc': 8187,
#          'die': 674,
#          'homemad': 813,
#          'berri': 129,
#          'jam': 310,
#          'butter': 1124,
#          'aioli': 176,
#          'mapl': 204,
#          'infus': 81,
#          'cornbread': 224,
#          'take': 6025,
#          'depend': 286,
#          'floor': 726,
#          'picnic': 131,
#          'ago': 1191,
#          'sat': 1785,
#          'avail': 1021,
#          'covid': 401,
#          'wear': 409,
#          'mask': 269,
#          'fall': 449,
#          'guest': 606,
#          'shoulder': 86,
#          'els': 2258,
#          'add': 1377,
#          'hook': 170,
#          'set': 1261,
#          'cleanest': 31,
#          'old': 2431,
#          'booster': 13,
#          'booth': 662,
#          'slide': 67,
#          'knee': 22,
#          'typic': 1131,
#          'huge': 2424,
#          'fan': 1748,
#          'adult': 311,
#          '10': 3631,
#          'usual': 2932,
#          'multipl': 616,
#          'quick': 2163,
#          'bathroom': 702,
#          'minut': 5727,
#          'meter': 131,
#          'follow': 561,
#          'bake': 1133,
#          'satan': 3,
#          'sammich': 27,
#          'freakin': 51,
#          'open': 3665,
#          'nearer': 5,
#          'huzzah': 3,
#          'reserv': 2208,
#          'earli': 1039,
#          'heather': 13,
#          'fantast': 2505,
#          'tuna': 640,
#          'mahi': 127,
#          'linguini': 28,
#          'pipe': 182,
#          'seven': 133,
#          'middl': 671,
#          'juici': 685,
#          'horseradish': 112,
#          'mash': 615,
#          'hole': 321,
#          'wall': 997,
#          'special': 4122,
#          'probabl': 2793,
#          'wast': 538,
#          'work': 4423,
#          'vibe': 1014,
#          'relax': 573,
#          'color': 414,
#          'cozi': 591,
#          'yummi': 1164,
#          'cuban': 370,
#          'diner': 933,
#          'la': 463,
#          'rosa': 16,
#          'today': 1866,
#          'late': 1256,
#          'mozzarella': 229,
#          'delux': 59,
#          'handtoss': 1,
#          'crust': 1698,
#          'serious': 927,
#          'maddi': 7,
#          'attent': 2365,
#          'pasta': 1419,
#          'mexican': 1485,
#          'fogata': 19,
#          'franchis': 115,
#          'concept': 538,
#          'accompani': 306,
#          'stellar': 230,
#          'friendliest': 52,
#          'wonder': 2737,
#          'given': 1107,
#          'extens': 287,
#          'bakersfield': 30,
#          'establish': 989,
#          'cinci': 55,
#          'rhine': 2,
#          'heard': 1115,
#          'everyon': 2412,
#          'killer': 167,
#          'honestli': 979,
#          'base': 1162,
#          'sole': 100,
#          'prep': 112,
#          'method': 43,
#          'spicier': 79,
#          'crunchier': 5,
#          'cajun': 314,
#          'heavili': 73,
#          'fatten': 10,
#          'drizzl': 182,
#          'ooz': 40,
#          'oil': 740,
#          'yeah': 433,
#          'popey': 55,
#          'funni': 290,
#          'trashi': 14,
#          'ahead': 694,
#          'judg': 201,
#          'free': 2779,
#          'rang': 368,
#          'boneless': 334,
#          'spici': 3527,
#          'hearti': 182,
#          'tap': 541,
#          'draft': 528,
#          'bottl': 1031,
#          'diversifi': 8,
#          'pay': 1818,
#          'variou': 299,
#          'rather': 980,
#          '4oz': 13,
#          'easi': 1135,
#          'warmer': 152,
#          'weather': 390,
#          'decid': 2680,
#          'indoor': 224,
#          'orlean': 105,
#          'coffe': 3313,
#          'refresh': 392,
#          'banana': 737,
#          'firm': 67,
#          'bit': 4618,
#          'sweeter': 86,
#          'prompt': 385,
#          'neither': 263,
#          'commun': 519,
#          'alcohol': 425,
#          'appl': 472,
#          'martini': 373,
#          'later': 1447,
#          'abl': 1470,
#          'line': 2814,
#          'steakhous': 361,
#          'cowboy': 62,
#          'sad': 565,
#          'roadhous': 55,
#          'dri': 1591,
#          'burnt': 437,
#          '71': 37,
#          'perfect': 4037,
#          'asparagu': 258,
#          'fact': 1061,
#          'sold': 262,
#          'separ': 421,
#          'à': 6,
#          'cart': 265,
#          'lobster': 863,
#          'bisqu': 367,
#          'soup': 3243,
#          'word': 686,
#          'frank': 118,
#          'fish': 2231,
#          'seafood': 939,
#          'market': 1477,
#          'grew': 167,
#          'south': 345,
#          'florida': 48,
#          'mile': 263,
#          'beach': 44,
#          'dozen': 337,
#          'fairli': 670,
#          'cod': 103,
#          'french': 1376,
#          'perch': 51,
#          'onion': 2021,
#          'ring': 508,
#          'kinda': 522,
#          'ate': 1524,
#          'car': 775,
#          'date': 1398,
#          'stone': 114,
#          'frankl': 1,
#          'soon': 1362,
#          'continu': 706,
#          'support': 425,
#          'tour': 145,
#          'quarantin': 40,
#          'run': 1499,
#          'chef': 1097,
#          'rich': 558,
#          'grab': 1090,
#          '6': 1824,
#          'coat': 223,
#          ...})

# %% [markdown]
# #### Define max number of words in a sequence
# * Setting this max number is important because we need to define a maximum sequence length that we can set to a number we pick
# * Note: Depending on the text, it is better to set this number high
# * (ex: Tweet - it is better to set this number to a high number between 50-70)
# * (ex: bigger text - you can set it to 200 or more)
# * In our trial, we're just going to start off small with 50 words
#
# The reason we need to define the sequence length is because when we use it with Tensorflow, we're going to need the same number of words/sequence length for each sequence.
#
# We won't be able to have sequences of different lengths. We need to map them to the same sequence size.

# %%
num_words = len(counter)

# Max number of words in a sequence
max_length = 50

# %% [markdown]
# #### Use the Tokenizer Class
#
# The next thing we need to use is the Tokenizer class from keras to tokenize the train sentences

# %%
# import the tokenizer from keras preprocessing 
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Fit the tokenizer onto the train sentences 
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(X_train)

# %%
# Pulls the word index from the tokenizer 
word_index = tokenizer.word_index

# This is an attribute of the tokenizer
# The attribute is a dictionary where
# key = actual word 
# value = the number that will now represent that word

# %%
word_index
# Out:
# {'food': 1,
#  'good': 2,
#  'place': 3,
#  'order': 4,
#  'great': 5,
#  'time': 6,
#  'like': 7,
#  'get': 8,
#  'go': 9,
#  'servic': 10,
#  'one': 11,
#  'back': 12,
#  'tri': 13,
#  'would': 14,
#  'realli': 15,
#  'chicken': 16,
#  'love': 17,
#  'restaur': 18,
#  'also': 19,
#  'got': 20,
#  'come': 21,
#  'drink': 22,
#  'menu': 23,
#  'even': 24,
#  'wait': 25,
#  'nice': 26,
#  'delici': 27,
#  'us': 28,
#  'well': 29,
#  'pizza': 30,
#  'best': 31,
#  'alway': 32,
#  'make': 33,
#  'bar': 34,
#  'fri': 35,
#  'tabl': 36,
#  'want': 37,
#  'sauc': 38,
#  'eat': 39,
#  'price': 40,
#  'littl': 41,
#  'look': 42,
#  'tast': 43,
#  'chees': 44,
#  'first': 45,
#  'came': 46,
#  'flavor': 47,
#  'definit': 48,
#  'staff': 49,
#  'meal': 50,
#  'salad': 51,
#  'friendli': 52,
#  'pretti': 53,
#  'columbu': 54,
#  'amaz': 55,
#  'never': 56,
#  'went': 57,
#  'experi': 58,
#  'could': 59,
#  'much': 60,
#  'ask': 61,
#  'made': 62,
#  'locat': 63,
#  'thing': 64,
#  'recommend': 65,
#  'peopl': 66,
#  'night': 67,
#  'take': 68,
#  'server': 69,
#  'side': 70,
#  'fresh': 71,
#  'sandwich': 72,
#  'say': 73,
#  'friend': 74,
#  'minut': 75,
#  'top': 76,
#  'better': 77,
#  'visit': 78,
#  'two': 79,
#  'enjoy': 80,
#  'dinner': 81,
#  'think': 82,
#  'lot': 83,
#  'favorit': 84,
#  'know': 85,
#  'everyth': 86,
#  'way': 87,
#  'seat': 88,
#  'day': 89,
#  'dish': 90,
#  'lunch': 91,
#  'hot': 92,
#  '2': 93,
#  'give': 94,
#  'busi': 95,
#  'hour': 96,
#  'serv': 97,
#  'ever': 98,
#  'still': 99,
#  '5': 100,
#  'said': 101,
#  'right': 102,
#  'sure': 103,
#  'star': 104,
#  'burger': 105,
#  'beer': 106,
#  'bit': 107,
#  'area': 108,
#  'new': 109,
#  'around': 110,
#  'need': 111,
#  'work': 112,
#  'seem': 113,
#  'disappoint': 114,
#  'small': 115,
#  'meat': 116,
#  'atmospher': 117,
#  'happi': 118,
#  'taco': 119,
#  'bread': 120,
#  'someth': 121,
#  'review': 122,
#  'cook': 123,
#  'special': 124,
#  '3': 125,
#  'though': 126,
#  'everi': 127,
#  'option': 128,
#  'perfect': 129,
#  'bad': 130,
#  'feel': 131,
#  'mani': 132,
#  'sinc': 133,
#  'see': 134,
#  'excel': 135,
#  'sweet': 136,
#  'custom': 137,
#  'anoth': 138,
#  'next': 139,
#  'took': 140,
#  'check': 141,
#  'last': 142,
#  'use': 143,
#  'open': 144,
#  'long': 145,
#  'stop': 146,
#  'year': 147,
#  'find': 148,
#  '10': 149,
#  'worth': 150,
#  'expect': 151,
#  'manag': 152,
#  'walk': 153,
#  'qualiti': 154,
#  'spici': 155,
#  'super': 156,
#  'roll': 157,
#  'tasti': 158,
#  'spot': 159,
#  'differ': 160,
#  'awesom': 161,
#  '4': 162,
#  'coffe': 163,
#  'dine': 164,
#  'enough': 165,
#  'wine': 166,
#  'select': 167,
#  'soup': 168,
#  'offer': 169,
#  'egg': 170,
#  'park': 171,
#  'portion': 172,
#  'call': 173,
#  'home': 174,
#  'steak': 175,
#  'big': 176,
#  'rice': 177,
#  'start': 178,
#  'breakfast': 179,
#  'overal': 180,
#  'potato': 181,
#  'sit': 182,
#  'appet': 183,
#  'help': 184,
#  'reason': 185,
#  'larg': 186,
#  'told': 187,
#  '1': 188,
#  'usual': 189,
#  'noth': 190,
#  'howev': 191,
#  'kind': 192,
#  'end': 193,
#  'line': 194,
#  'half': 195,
#  'probabl': 196,
#  'husband': 197,
#  'free': 198,
#  'high': 199,
#  'full': 200,
#  'clean': 201,
#  'person': 202,
#  'wonder': 203,
#  'item': 204,
#  'wing': 205,
#  'insid': 206,
#  'fast': 207,
#  'actual': 208,
#  'decid': 209,
#  'famili': 210,
#  'town': 211,
#  'week': 212,
#  'close': 213,
#  'mayb': 214,
#  'away': 215,
#  'plate': 216,
#  'waitress': 217,
#  'fantast': 218,
#  'shrimp': 219,
#  'absolut': 220,
#  'bowl': 221,
#  'thought': 222,
#  'hous': 223,
#  'let': 224,
#  'dessert': 225,
#  'ok': 226,
#  'put': 227,
#  'quit': 228,
#  'live': 229,
#  'old': 230,
#  'huge': 231,
#  'cold': 232,
#  'everyon': 233,
#  'anyth': 234,
#  'return': 235,
#  'left': 236,
#  'patio': 237,
#  'pork': 238,
#  'attent': 239,
#  'fun': 240,
#  'local': 241,
#  'pick': 242,
#  'size': 243,
#  'els': 244,
#  'cocktail': 245,
#  'arriv': 246,
#  'short': 247,
#  'without': 248,
#  'fish': 249,
#  'drive': 250,
#  'reserv': 251,
#  'found': 252,
#  'point': 253,
#  'choic': 254,
#  'tell': 255,
#  'quick': 256,
#  'wife': 257,
#  'room': 258,
#  'highli': 259,
#  'chip': 260,
#  'final': 261,
#  'decent': 262,
#  'almost': 263,
#  'outsid': 264,
#  'hard': 265,
#  'impress': 266,
#  'fill': 267,
#  'ice': 268,
#  'mac': 269,
#  'coupl': 270,
#  'cream': 271,
#  'sushi': 272,
#  'bacon': 273,
#  'sever': 274,
#  'warm': 275,
#  'bartend': 276,
#  'waiter': 277,
#  'onion': 278,
#  'beef': 279,
#  'tea': 280,
#  'owner': 281,
#  'hand': 282,
#  'three': 283,
#  'group': 284,
#  'north': 285,
#  'kid': 286,
#  'water': 287,
#  'season': 288,
#  'keep': 289,
#  'care': 290,
#  'especi': 291,
#  'cool': 292,
#  'game': 293,
#  'wrong': 294,
#  'veggi': 295,
#  'bring': 296,
#  'entre': 297,
#  'far': 298,
#  'leav': 299,
#  'gave': 300,
#  'today': 301,
#  '20': 302,
#  'least': 303,
#  'extra': 304,
#  'gener': 305,
#  'thank': 306,
#  '30': 307,
#  'guy': 308,
#  'decor': 309,
#  'door': 310,
#  'must': 311,
#  '6': 312,
#  'second': 313,
#  'pay': 314,
#  'grill': 315,
#  'perfectli': 316,
#  'bean': 317,
#  'brought': 318,
#  'hope': 319,
#  'done': 320,
#  'parti': 321,
#  'part': 322,
#  'sat': 323,
#  'fan': 324,
#  'chines': 325,
#  'bite': 326,
#  'brunch': 327,
#  'someon': 328,
#  'light': 329,
#  'style': 330,
#  'may': 331,
#  'crust': 332,
#  'crowd': 333,
#  'share': 334,
#  'name': 335,
#  'chang': 336,
#  '15': 337,
#  'wish': 338,
#  'front': 339,
#  'plenti': 340,
#  'whole': 341,
#  'oh': 342,
#  'street': 343,
#  'piec': 344,
#  'includ': 345,
#  'crispi': 346,
#  'green': 347,
#  'red': 348,
#  'instead': 349,
#  'amount': 350,
#  'regular': 351,
#  'surpris': 352,
#  'dri': 353,
#  'space': 354,
#  'employe': 355,
#  'fine': 356,
#  'cours': 357,
#  'miss': 358,
#  'either': 359,
#  'slow': 360,
#  'saturday': 361,
#  'citi': 362,
#  'less': 363,
#  'prepar': 364,
#  'ate': 365,
#  'okay': 366,
#  'mix': 367,
#  'shop': 368,
#  'extrem': 369,
#  'might': 370,
#  'move': 371,
#  'run': 372,
#  'yet': 373,
#  'donut': 374,
#  'felt': 375,
#  'cake': 376,
#  'mexican': 377,
#  'market': 378,
#  'store': 379,
#  'abl': 380,
#  'often': 381,
#  'pepper': 382,
#  'pleas': 383,
#  'italian': 384,
#  'rib': 385,
#  'white': 386,
#  'deal': 387,
#  'later': 388,
#  'ingredi': 389,
#  'money': 390,
#  'sunday': 391,
#  'quickli': 392,
#  'show': 393,
#  'list': 394,
#  'glass': 395,
#  'beauti': 396,
#  'kitchen': 397,
#  'incred': 398,
#  'talk': 399,
#  'weekend': 400,
#  'thai': 401,
#  'spice': 402,
#  'pasta': 403,
#  '8': 404,
#  'total': 405,
#  'watch': 406,
#  'real': 407,
#  'mean': 408,
#  'date': 409,
#  'receiv': 410,
#  'although': 411,
#  'slice': 412,
#  'varieti': 413,
#  'dress': 414,
#  'gyro': 415,
#  'tomato': 416,
#  'add': 417,
#  'french': 418,
#  'finish': 419,
#  '7': 420,
#  'soon': 421,
#  'consist': 422,
#  'tender': 423,
#  'suggest': 424,
#  'bbq': 425,
#  'ye': 426,
#  'music': 427,
#  'dip': 428,
#  'authent': 429,
#  'averag': 430,
#  'counter': 431,
#  'pack': 432,
#  'terribl': 433,
#  'play': 434,
#  'tip': 435,
#  'past': 436,
#  'sub': 437,
#  'ohio': 438,
#  'ad': 439,
#  'readi': 440,
#  'happen': 441,
#  'salmon': 442,
#  'set': 443,
#  'late': 444,
#  'crab': 445,
#  'birthday': 446,
#  'friday': 447,
#  'cut': 448,
#  'complet': 449,
#  'toast': 450,
#  'anyon': 451,
#  'burrito': 452,
#  'worst': 453,
#  'except': 454,
#  'rememb': 455,
#  'salsa': 456,
#  'hit': 457,
#  'issu': 458,
#  'uniqu': 459,
#  'ago': 460,
#  'problem': 461,
#  'stay': 462,
#  'type': 463,
#  'chipotl': 464,
#  'alreadi': 465,
#  'chocol': 466,
#  'lack': 467,
#  'turn': 468,
#  'stand': 469,
#  'yummi': 470,
#  'saw': 471,
#  'plu': 472,
#  'charg': 473,
#  'sometim': 474,
#  'base': 475,
#  'rude': 476,
#  'yelp': 477,
#  'excit': 478,
#  'recent': 479,
#  'mention': 480,
#  'ambianc': 481,
#  'choos': 482,
#  'glad': 483,
#  'cup': 484,
#  'entir': 485,
#  'easi': 486,
#  'bake': 487,
#  'trip': 488,
#  'typic': 489,
#  'greek': 490,
#  'month': 491,
#  'pie': 492,
#  'butter': 493,
#  'garlic': 494,
#  'deliveri': 495,
#  'heard': 496,
#  'vegetarian': 497,
#  'comfort': 498,
#  'given': 499,
#  'bill': 500,
#  'mind': 501,
#  'interest': 502,
#  'chef': 503,
#  'twice': 504,
#  'grab': 505,
#  '50': 506,
#  'treat': 507,
#  'greet': 508,
#  'sausag': 509,
#  'believ': 510,
#  'main': 511,
#  'addit': 512,
#  'bland': 513,
#  'normal': 514,
#  'corn': 515,
#  'buffet': 516,
#  'cheap': 517,
#  'noodl': 518,
#  'eaten': 519,
#  'job': 520,
#  'fact': 521,
#  'notic': 522,
#  'wrap': 523,
#  'guess': 524,
#  'veget': 525,
#  'expens': 526,
#  'head': 527,
#  'understand': 528,
#  'basic': 529,
#  'earli': 530,
#  'deliv': 531,
#  'tonight': 532,
#  'togeth': 533,
#  'bottl': 534,
#  'five': 535,
#  'avail': 536,
#  'pho': 537,
#  'mushroom': 538,
#  'vibe': 539,
#  'rate': 540,
#  'welcom': 541,
#  'other': 542,
#  'liter': 543,
#  'read': 544,
#  'wow': 545,
#  'four': 546,
#  'simpl': 547,
#  'wall': 548,
#  'pickl': 549,
#  'establish': 550,
#  'standard': 551,
#  'boyfriend': 552,
#  'rather': 553,
#  'lamb': 554,
#  'honestli': 555,
#  'yum': 556,
#  'unfortun': 557,
#  'pita': 558,
#  'stuff': 559,
#  'medium': 560,
#  'consid': 561,
#  'along': 562,
#  'brisket': 563,
#  'etc': 564,
#  '9': 565,
#  'behind': 566,
#  'morn': 567,
#  'window': 568,
#  'black': 569,
#  'complaint': 570,
#  'downtown': 571,
#  'girl': 572,
#  'min': 573,
#  'seafood': 574,
#  'horribl': 575,
#  'card': 576,
#  'due': 577,
#  'pull': 578,
#  'loud': 579,
#  'diner': 580,
#  'solid': 581,
#  'pricey': 582,
#  'serious': 583,
#  'plan': 584,
#  'casual': 585,
#  'level': 586,
#  'build': 587,
#  'gone': 588,
#  'forward': 589,
#  'chain': 590,
#  'vegan': 591,
#  'outstand': 592,
#  'near': 593,
#  'roast': 594,
#  'salt': 595,
#  'crave': 596,
#  'lettuc': 597,
#  'phone': 598,
#  'prefer': 599,
#  'empti': 600,
#  'appreci': 601,
#  'cafe': 602,
#  'soft': 603,
#  '12': 604,
#  'immedi': 605,
#  'heat': 606,
#  'hostess': 607,
#  'hummu': 608,
#  'kept': 609,
#  'life': 610,
#  'lobster': 611,
#  'across': 612,
#  'split': 613,
#  'stick': 614,
#  'refil': 615,
#  'n': 616,
#  'salti': 617,
#  'rest': 618,
#  'mouth': 619,
#  'bun': 620,
#  'seen': 621,
#  'truck': 622,
#  'event': 623,
#  'brown': 624,
#  'ladi': 625,
#  'pancak': 626,
#  'pastor': 627,
#  'sampl': 628,
#  'hungri': 629,
#  'paid': 630,
#  'man': 631,
#  'note': 632,
#  'thru': 633,
#  'carri': 634,
#  'poor': 635,
#  'meatbal': 636,
#  'ton': 637,
#  'pleasant': 638,
#  'rare': 639,
#  'homemad': 640,
#  'anyway': 641,
#  'sour': 642,
#  'onlin': 643,
#  'app': 644,
#  'hear': 645,
#  'joint': 646,
#  'cute': 647,
#  'smoke': 648,
#  'neighborhood': 649,
#  'dark': 650,
#  'sign': 651,
#  'gluten': 652,
#  'knew': 653,
#  'cover': 654,
#  'margarita': 655,
#  'limit': 656,
#  'chanc': 657,
#  'present': 658,
#  'sound': 659,
#  'write': 660,
#  'request': 661,
#  'melt': 662,
#  'cost': 663,
#  'car': 664,
#  'world': 665,
#  'thin': 666,
#  'greasi': 667,
#  'explain': 668,
#  'pepperoni': 669,
#  'waffl': 670,
#  'compar': 671,
#  'bagel': 672,
#  'bag': 673,
#  'buy': 674,
#  'provid': 675,
#  'spend': 676,
#  'tradit': 677,
#  'satisfi': 678,
#  'meet': 679,
#  'oil': 680,
#  'rush': 681,
#  'accommod': 682,
#  'pass': 683,
#  'banana': 684,
#  'question': 685,
#  'apolog': 686,
#  'thick': 687,
#  'healthi': 688,
#  'chili': 689,
#  'biscuit': 690,
#  'floor': 691,
#  'al': 692,
#  'combo': 693,
#  'oyster': 694,
#  'slightli': 695,
#  'gem': 696,
#  'smell': 697,
#  'save': 698,
#  'box': 699,
#  'dirti': 700,
#  'frequent': 701,
#  'singl': 702,
#  'state': 703,
#  'calamari': 704,
#  'asian': 705,
#  'pictur': 706,
#  'falafel': 707,
#  'continu': 708,
#  'strip': 709,
#  'bathroom': 710,
#  'taken': 711,
#  'valu': 712,
#  'indian': 713,
#  'realiz': 714,
#  'pastri': 715,
#  'knowledg': 716,
#  'ahead': 717,
#  'low': 718,
#  'mine': 719,
#  'simpli': 720,
#  'touch': 721,
#  'number': 722,
#  'exactli': 723,
#  'word': 724,
#  'sorri': 725,
#  'juici': 726,
#  'idea': 727,
#  'american': 728,
#  'pad': 729,
#  'truli': 730,
#  'origin': 731,
#  'die': 732,
#  'middl': 733,
#  'worker': 734,
#  'lemon': 735,
#  'classic': 736,
#  'fairli': 737,
#  'tv': 738,
#  'creami': 739,
#  'notch': 740,
#  'stuf': 741,
#  '45': 742,
#  'longer': 743,
#  'upon': 744,
#  'son': 745,
#  'easili': 746,
#  'suppos': 747,
#  'booth': 748,
#  'doubl': 749,
#  'mediocr': 750,
#  'filet': 751,
#  '25': 752,
#  'summer': 753,
#  'chop': 754,
#  'ranch': 755,
#  'crisp': 756,
#  'interior': 757,
#  'combin': 758,
#  'patron': 759,
#  'sort': 760,
#  'mom': 761,
#  'hotel': 762,
#  'celebr': 763,
#  'certainli': 764,
#  'cannot': 765,
#  'club': 766,
#  'cinnamon': 767,
#  'convers': 768,
#  'tuna': 769,
#  'speak': 770,
#  'fix': 771,
#  'mostli': 772,
#  'possibl': 773,
#  'afternoon': 774,
#  'hang': 775,
#  'updat': 776,
#  'anywher': 777,
#  'curri': 778,
#  'opinion': 779,
#  'eye': 780,
#  'slaw': 781,
#  'outdoor': 782,
#  'view': 783,
#  'avocado': 784,
#  'cheesecak': 785,
#  'honey': 786,
#  'cooki': 787,
#  'bare': 788,
#  'gotten': 789,
#  'overpr': 790,
#  'multipl': 791,
#  'easton': 792,
#  'mash': 793,
#  'scallop': 794,
#  'occas': 795,
#  'figur': 796,
#  'chose': 797,
#  'aw': 798,
#  'oliv': 799,
#  'daughter': 800,
#  'remind': 801,
#  '00': 802,
#  'forget': 803,
#  'guest': 804,
#  'mess': 805,
#  'textur': 806,
#  'goe': 807,
#  'answer': 808,
#  'smile': 809,
#  'case': 810,
#  'monday': 811,
#  'fair': 812,
#  'pop': 813,
#  'complain': 814,
#  '11': 815,
#  'cozi': 816,
#  'spinach': 817,
#  'polit': 818,
#  'forgot': 819,
#  'beyond': 820,
#  'dumpl': 821,
#  'whatev': 822,
#  'non': 823,
#  'tortilla': 824,
#  'drop': 825,
#  'within': 826,
#  'matter': 827,
#  'unless': 828,
#  'environ': 829,
#  'boy': 830,
#  'delight': 831,
#  'sprout': 832,
#  'face': 833,
#  'relax': 834,
#  'crazi': 835,
#  'hate': 836,
#  'gravi': 837,
#  'beat': 838,
#  'shot': 839,
#  'sad': 840,
#  '40': 841,
#  'appear': 842,
#  'avoid': 843,
#  'fanci': 844,
#  'book': 845,
#  'weird': 846,
#  'follow': 847,
#  'young': 848,
#  'rich': 849,
#  'kick': 850,
#  'hold': 851,
#  'craft': 852,
#  'pud': 853,
#  'becom': 854,
#  'clearli': 855,
#  'broth': 856,
#  'smaller': 857,
#  'mediterranean': 858,
#  'tuesday': 859,
#  'tap': 860,
#  'somewher': 861,
#  'alon': 862,
#  'wast': 863,
#  'concept': 864,
#  'correct': 865,
#  'tini': 866,
#  'w': 867,
#  'takeout': 868,
#  'corner': 869,
#  'strong': 870,
#  'draft': 871,
#  'villag': 872,
#  'host': 873,
#  'dollar': 874,
#  'turkey': 875,
#  'step': 876,
#  'blue': 877,
#  'load': 878,
#  'kinda': 879,
#  'clear': 880,
#  'phenomen': 881,
#  'commun': 882,
#  'road': 883,
#  'true': 884,
#  'sugar': 885,
#  'crunchi': 886,
#  'carrot': 887,
#  'tofu': 888,
#  'frozen': 889,
#  'spring': 890,
#  'buck': 891,
#  'ring': 892,
#  'pour': 893,
#  'girlfriend': 894,
#  'lol': 895,
#  'fire': 896,
#  'fabul': 897,
#  'obvious': 898,
#  'brew': 899,
#  'appar': 900,
#  'profession': 901,
#  'folk': 902,
#  'futur': 903,
#  'allow': 904,
#  'lucki': 905,
#  'mistak': 906,
#  'plain': 907,
#  'fruit': 908,
#  'raw': 909,
#  'chair': 910,
#  'mall': 911,
#  'school': 912,
#  'juic': 913,
#  'round': 914,
#  'coupon': 915,
#  'spent': 916,
#  'mcdonald': 917,
#  'heavi': 918,
#  'none': 919,
#  'sport': 920,
#  'inform': 921,
#  'ball': 922,
#  'dog': 923,
#  'post': 924,
#  'pm': 925,
#  'product': 926,
#  'balanc': 927,
#  'similar': 928,
#  'appl': 929,
#  'opt': 930,
#  'rave': 931,
#  'hidden': 932,
#  'leftov': 933,
#  'ridicul': 934,
#  'parmesan': 935,
#  'quesadilla': 936,
#  'chorizo': 937,
#  'attitud': 938,
#  'despit': 939,
#  '100': 940,
#  'la': 941,
#  'nacho': 942,
#  'otherwis': 943,
#  'peanut': 944,
#  'contain': 945,
#  'ramen': 946,
#  'neg': 947,
#  'agre': 948,
#  'met': 949,
#  'afford': 950,
#  'hash': 951,
#  'northstar': 952,
#  'confus': 953,
#  'fall': 954,
#  'perhap': 955,
#  'nearli': 956,
#  'break': 957,
#  'soggi': 958,
#  'tough': 959,
#  'popular': 960,
#  'bone': 961,
#  'mood': 962,
#  'conveni': 963,
#  'giant': 964,
#  'comment': 965,
#  'bottom': 966,
#  'platter': 967,
#  'effici': 968,
#  'per': 969,
#  'burnt': 970,
#  'pineappl': 971,
#  'difficult': 972,
#  'pot': 973,
#  'forev': 974,
#  'posit': 975,
#  'brussel': 976,
#  'handl': 977,
#  'yeah': 978,
#  'rock': 979,
#  'modern': 980,
#  'soda': 981,
#  'pair': 982,
#  'deep': 983,
#  'nearbi': 984,
#  'section': 985,
#  'imagin': 986,
#  'dublin': 987,
#  'travel': 988,
#  'improv': 989,
#  'awhil': 990,
#  'heart': 991,
#  'alcohol': 992,
#  'support': 993,
#  'groceri': 994,
#  'bakeri': 995,
#  'separ': 996,
#  'buffalo': 997,
#  'credit': 998,
#  'goat': 999,
#  'version': 1000,
#  ...}

# %%
# Creates the sequences from our tokenizer, based on the indices from the word_index
train_sequences = tokenizer.texts_to_sequences(X_train)

# %%
X_train.values[0]
# Out:
# 'look breakfast place town tri stumbl upon mccarthi smaller size resteraunt think make due space busi saturday afternoon expect got tabl pretti quickli order skillet scrambler pancak signific got egg benedict skillet good howev call skillet like scrambl egg minc meat side scallop potato potato melt mouth good egg cook excel toast brought delici pancak superb size plate nice circumfer also thicker pancak great tast great said egg benedict alright egg slightli undercook hollandais alright much flavor also would like ham thicker piec ham instead shave use overal price reason food good servic nice throughout visit definit go back'

# %%
train_sequences[0]  # This sequence has 24 words
# Out:
# [42,
#  179,
#  3,
#  211,
#  13,
#  1754,
#  744,
#  10483,
#  857,
#  243,
#  8880,
#  82,
#  33,
#  577,
#  354,
#  95,
#  361,
#  774,
#  151,
#  20,
#  36,
#  53,
#  392,
#  4,
#  1611,
#  3632,
#  626,
#  3045,
#  20,
#  170,
#  1950,
#  1611,
#  2,
#  191,
#  173,
#  1611,
#  7,
#  1734,
#  170,
#  4798,
#  116,
#  70,
#  794,
#  181,
#  181,
#  662,
#  619,
#  2,
#  170,
#  123,
#  135,
#  450,
#  318,
#  27,
#  626,
#  1313,
#  243,
#  216,
#  26,
#  9572,
#  19,
#  2317,
#  626,
#  5,
#  43,
#  5,
#  101,
#  170,
#  1950,
#  1284,
#  170,
#  695,
#  1448,
#  3097,
#  1284,
#  60,
#  47,
#  19,
#  14,
#  7,
#  1090,
#  2317,
#  344,
#  1090,
#  349,
#  2584,
#  143,
#  180,
#  40,
#  185,
#  1,
#  2,
#  10,
#  26,
#  1099,
#  78,
#  48,
#  9,
#  12]

# %%
len(train_sequences[0])
# Out:
# 99

# %%
# Now adding padding
from tensorflow.keras.preprocessing.sequence import pad_sequences 

train_padded = pad_sequences(
    train_sequences, maxlen=max_length, padding='post', truncating='post'
)
# Out:
# Using TensorFlow backend.

# %%
train_padded[0]
# Out:
# array([   42,   179,     3,   211,    13,  1754,   744, 10483,   857,
#          243,  8880,    82,    33,   577,   354,    95,   361,   774,
#          151,    20,    36,    53,   392,     4,  1611,  3632,   626,
#         3045,    20,   170,  1950,  1611,     2,   191,   173,  1611,
#            7,  1734,   170,  4798,   116,    70,   794,   181,   181,
#          662,   619,     2,   170,   123,   135,   450,   318,    27,
#          626,  1313,   243,   216,    26,  9572,    19,  2317,   626,
#            5,    43,     5,   101,   170,  1950,  1284,   170,   695,
#         1448,  3097,  1284,    60,    47,    19,    14,     7,  1090,
#         2317,   344,  1090,   349,  2584,   143,   180,    40,   185,
#            1,     2,    10,    26,  1099,    78,    48,     9,    12,
#            0], dtype=int32)

# %%
# Creates the test dataset sequences and padding
test_sequences = tokenizer.texts_to_sequences(X_test)
test_padded = pad_sequences(
    test_sequences, maxlen=max_length, padding='post', truncating='post'
)

# %%
print(X_train.values[0])
print(train_sequences[0])
# Out:
# look breakfast place town tri stumbl upon mccarthi smaller size resteraunt think make due space busi saturday afternoon expect got tabl pretti quickli order skillet scrambler pancak signific got egg benedict skillet good howev call skillet like scrambl egg minc meat side scallop potato potato melt mouth good egg cook excel toast brought delici pancak superb size plate nice circumfer also thicker pancak great tast great said egg benedict alright egg slightli undercook hollandais alright much flavor also would like ham thicker piec ham instead shave use overal price reason food good servic nice throughout visit definit go back
# [42, 179, 3, 211, 13, 1754, 744, 10483, 857, 243, 8880, 82, 33, 577, 354, 95, 361, 774, 151, 20, 36, 53, 392, 4, 1611, 3632, 626, 3045, 20, 170, 1950, 1611, 2, 191, 173, 1611, 7, 1734, 170, 4798, 116, 70, 794, 181, 181, 662, 619, 2, 170, 123, 135, 450, 318, 27, 626, 1313, 243, 216, 26, 9572, 19, 2317, 626, 5, 43, 5, 101, 170, 1950, 1284, 170, 695, 1448, 3097, 1284, 60, 47, 19, 14, 7, 1090, 2317, 344, 1090, 349, 2584, 143, 180, 40, 185, 1, 2, 10, 26, 1099, 78, 48, 9, 12]

# %%
# Checks to make sure that you can decode in reverse 
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

decode(train_sequences[0])
# Out:
# 'look breakfast place town tri stumbl upon mccarthi smaller size resteraunt think make due space busi saturday afternoon expect got tabl pretti quickli order skillet scrambler pancak signific got egg benedict skillet good howev call skillet like scrambl egg minc meat side scallop potato potato melt mouth good egg cook excel toast brought delici pancak superb size plate nice circumfer also thicker pancak great tast great said egg benedict alright egg slightli undercook hollandais alright much flavor also would like ham thicker piec ham instead shave use overal price reason food good servic nice throughout visit definit go back'

# %%
# Checks the shape of the train and the shape of the test
print(f'Shape of train {train_padded.shape}')
print(f'Shape of test {test_padded.shape}')
# Out:
# Shape of train (48650, 100)
# Shape of test (16217, 100)

# %% [markdown]
# ### Set up the Network topology
#
# * We could've used One Hot Encoding (OHE) to convert these indices into vectors of 0s an 1s, but this would increase the dimensionality of our features
#
# **Instead...**
# * The Embedding layer - maps each word to a vector of a fixed size with real value elements...
# * In contrast to One Hot Encoding, we can use finite size vector to represent an infinite number of real numbers.
# * We're going to use dimensionality of this embedding layer (32) and the input length will be the max length

# %%
# Sets up network topology 
model = Sequential()

model.add(Embedding(num_words, 32, input_length=max_length))
model.add(LSTM(64, dropout=0.1))
model.add(Dense(4, activation='softmax'))

optimizer = Adam(lr=3e-4)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

# %%
# model_l.add(Bidirectional(LSTM(24)))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 100, 32)           900864
# _________________________________________________________________
# lstm (LSTM)                  (None, 64)                24832
# _________________________________________________________________
# dense (Dense)                (None, 4)                 260
# =================================================================
# Total params: 925,956
# Trainable params: 925,956
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history = model.fit(
    train_padded, y_train, epochs=25, batch_size=256, 
    validation_data=(test_padded, y_test)
)
# Out:
# Epoch 1/25
# 191/191 [==============================] - 106s 557ms/step - loss: 0.9951 - acc: 0.5523 - val_loss: 1.0272 - val_acc: 0.5415
# Epoch 2/25
# 191/191 [==============================] - 110s 576ms/step - loss: 0.9379 - acc: 0.5974 - val_loss: 1.0175 - val_acc: 0.5479
# Epoch 3/25
# 191/191 [==============================] - 108s 565ms/step - loss: 0.8951 - acc: 0.6260 - val_loss: 1.1013 - val_acc: 0.5425
# Epoch 4/25
# 191/191 [==============================] - 111s 579ms/step - loss: 0.8679 - acc: 0.6426 - val_loss: 1.0705 - val_acc: 0.5372
# Epoch 5/25
# 191/191 [==============================] - 108s 565ms/step - loss: 0.8326 - acc: 0.6667 - val_loss: 0.9993 - val_acc: 0.5759
# Epoch 6/25
# 191/191 [==============================] - 105s 549ms/step - loss: 0.8102 - acc: 0.6816 - val_loss: 1.0114 - val_acc: 0.5811
# Epoch 7/25
# 191/191 [==============================] - 105s 549ms/step - loss: 0.7838 - acc: 0.6982 - val_loss: 1.0126 - val_acc: 0.5706
# Epoch 8/25
# 191/191 [==============================] - 107s 559ms/step - loss: 0.7603 - acc: 0.7104 - val_loss: 1.0517 - val_acc: 0.5848
# Epoch 9/25
# 191/191 [==============================] - 107s 561ms/step - loss: 0.7288 - acc: 0.7244 - val_loss: 0.9996 - val_acc: 0.5970
# Epoch 10/25
# 191/191 [==============================] - 104s 546ms/step - loss: 0.6906 - acc: 0.7393 - val_loss: 1.0026 - val_acc: 0.5796
# Epoch 11/25
# 191/191 [==============================] - 107s 561ms/step - loss: 0.6624 - acc: 0.7519 - val_loss: 1.0164 - val_acc: 0.6071
# Epoch 12/25
# 191/191 [==============================] - 110s 574ms/step - loss: 0.6426 - acc: 0.7602 - val_loss: 1.0009 - val_acc: 0.6053
# Epoch 13/25
# 191/191 [==============================] - 108s 564ms/step - loss: 0.6171 - acc: 0.7690 - val_loss: 1.0396 - val_acc: 0.6025
# Epoch 14/25
# 191/191 [==============================] - 105s 552ms/step - loss: 0.5904 - acc: 0.7790 - val_loss: 1.0270 - val_acc: 0.6200
# Epoch 15/25
# 191/191 [==============================] - 105s 550ms/step - loss: 0.5676 - acc: 0.7870 - val_loss: 1.0222 - val_acc: 0.6111
# Epoch 16/25
# 191/191 [==============================] - 109s 572ms/step - loss: 0.5446 - acc: 0.7953 - val_loss: 1.1067 - val_acc: 0.6145
# Epoch 17/25
# 191/191 [==============================] - 111s 580ms/step - loss: 0.5369 - acc: 0.7951 - val_loss: 1.0535 - val_acc: 0.6150
# Epoch 18/25
# 191/191 [==============================] - 115s 604ms/step - loss: 0.5164 - acc: 0.8037 - val_loss: 1.0374 - val_acc: 0.6118
# Epoch 19/25
# 191/191 [==============================] - 110s 577ms/step - loss: 0.4995 - acc: 0.8105 - val_loss: 1.0585 - val_acc: 0.6139
# Epoch 20/25
# 191/191 [==============================] - 107s 562ms/step - loss: 0.4974 - acc: 0.8091 - val_loss: 1.0842 - val_acc: 0.6113
# Epoch 21/25
# 191/191 [==============================] - 108s 564ms/step - loss: 0.4764 - acc: 0.8182 - val_loss: 1.1122 - val_acc: 0.6092
# Epoch 22/25
# 191/191 [==============================] - 105s 550ms/step - loss: 0.4692 - acc: 0.8196 - val_loss: 1.1307 - val_acc: 0.6206
# Epoch 23/25
# 191/191 [==============================] - 107s 562ms/step - loss: 0.4606 - acc: 0.8212 - val_loss: 1.2028 - val_acc: 0.6218
# Epoch 24/25
# 191/191 [==============================] - 105s 551ms/step - loss: 0.4517 - acc: 0.8244 - val_loss: 1.1669 - val_acc: 0.6171
# Epoch 25/25
# 191/191 [==============================] - 107s 559ms/step - loss: 0.4426 - acc: 0.8293 - val_loss: 1.1943 - val_acc: 0.6208

# %%
df['amb_target'].value_counts(normalize=True)
# Out:
# 1    0.328703
# 3    0.279911
# 2    0.207394
# 0    0.183992
# Name: amb_target, dtype: float64

# %% [markdown]
# ## 2) Modeling with original text with stopwords removed

# %%
# Sets up X and y
X2 = df['clean_text']
y2 = df['amb_target']

# %%
# One-hot encoding for the categorical y response variable 
y2 = to_categorical(y2)

# %%
# Splits the data into training and test sets from sample
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, 
                                                    stratify=y2, 
                                                    random_state=42)

# %%
X_train2
# Out:
# 8210     looking breakfast place town try stumbled upon...
# 12563    love mohawk atmosphere food outstanding bad th...
# 55374    tried several chinese places powell worth ment...
# 34856    boyfriend stopped dinner first night driving a...
# 17500    stopped ice cream treat dinner main street lov...
#                                ...
# 47234    great food comfortable atmosphere food great g...
# 49006    bang buck price got awesome mediterrenean food...
# 62754    bibibop nice wide selection fresh ingredients ...
# 25465    best service small operation much staff partly...
# 26940    chicken avocado sandwich favorite mine none fo...
# Name: clean_text, Length: 48650, dtype: object

# %% [markdown]
# ### Basic NLP

# %%
# import the Counter function
from collections import Counter

# import the tokenizer from keras preprocessing 
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Creates a function that counts unique words
def counter_word(text):
    count = Counter()
    for doc in text.values:
        for word in doc.split():
            count[word] += 1
    return count

# %%
X_train2
# Out:
# 8210     looking breakfast place town try stumbled upon...
# 12563    love mohawk atmosphere food outstanding bad th...
# 55374    tried several chinese places powell worth ment...
# 34856    boyfriend stopped dinner first night driving a...
# 17500    stopped ice cream treat dinner main street lov...
#                                ...
# 47234    great food comfortable atmosphere food great g...
# 49006    bang buck price got awesome mediterrenean food...
# 62754    bibibop nice wide selection fresh ingredients ...
# 25465    best service small operation much staff partly...
# 26940    chicken avocado sandwich favorite mine none fo...
# Name: clean_text, Length: 48650, dtype: object

# %%
X_train2.values[0]
# Out:
# "looking breakfast place town try stumbled upon mccarthy' it' smaller sized resteraunt think make due space busy saturday afternoon expected got table pretty quickly ordered skillet scrambler pancake significant got eggs benedict skillet good however wouldn' call skillet like scrambled eggs minced meats side scalloped potatoes potatoes melt mouth good eggs cooked excellently toast brought delicious pancake superb size plate nice circumference also thicker pancake great tasted great said eggs benedict alright eggs slightly undercooked hollandaise alright didn' much flavor also would liked ham thicker piece ham instead shaved use overall price reasonable food good service nice throughout visit definitely going back"

# %%
# Counts the number of times a unique word appears
counter = counter_word(X_train2)

# %%
# Finds the length or the number of unique words
len(counter)
# Out:
# 42840

# %%
counter
# Out:
# Counter({'looking': 2886,
#          'breakfast': 3024,
#          'place': 24056,
#          'town': 2545,
#          'try': 8170,
#          'stumbled': 138,
#          'upon': 665,
#          "mccarthy'": 4,
#          "it'": 15735,
#          'smaller': 545,
#          'sized': 413,
#          'resteraunt': 6,
#          'think': 4894,
#          'make': 5616,
#          'due': 934,
#          'space': 1459,
#          'busy': 3029,
#          'saturday': 1461,
#          'afternoon': 614,
#          'expected': 996,
#          'got': 11132,
#          'table': 5646,
#          'pretty': 6884,
#          'quickly': 1435,
#          'ordered': 10953,
#          'skillet': 199,
#          'scrambler': 27,
#          'pancake': 187,
#          'significant': 63,
#          'eggs': 1294,
#          'benedict': 143,
#          'good': 30013,
#          'however': 2895,
#          "wouldn'": 1310,
#          'call': 1315,
#          'like': 17618,
#          'scrambled': 137,
#          'minced': 24,
#          'meats': 685,
#          'side': 4614,
#          'scalloped': 16,
#          'potatoes': 1673,
#          'melt': 342,
#          'mouth': 803,
#          'cooked': 2885,
#          'excellently': 33,
#          'toast': 949,
#          'brought': 1802,
#          'delicious': 9261,
#          'superb': 280,
#          'size': 1538,
#          'plate': 1519,
#          'nice': 8909,
#          'circumference': 5,
#          'also': 11362,
#          'thicker': 108,
#          'great': 23616,
#          'tasted': 2412,
#          'said': 4840,
#          'alright': 286,
#          'slightly': 722,
#          'undercooked': 239,
#          'hollandaise': 62,
#          "didn'": 6798,
#          'much': 6554,
#          'flavor': 4038,
#          'would': 12881,
#          'liked': 1531,
#          'ham': 365,
#          'piece': 814,
#          'instead': 1613,
#          'shaved': 62,
#          'use': 1503,
#          'overall': 3047,
#          'price': 3618,
#          'reasonable': 1058,
#          'food': 35629,
#          'service': 17118,
#          'throughout': 366,
#          'visit': 3504,
#          'definitely': 7152,
#          'going': 4841,
#          'back': 14393,
#          'love': 8832,
#          'mohawk': 161,
#          'atmosphere': 4275,
#          'outstanding': 911,
#          'bad': 4013,
#          'thing': 3222,
#          'say': 4615,
#          'parking': 2569,
#          'sucks': 222,
#          'must': 1790,
#          'suck': 80,
#          'go': 13794,
#          'restaurant': 10087,
#          'glad': 1145,
#          'tried': 4315,
#          'several': 1921,
#          'chinese': 1729,
#          'places': 2865,
#          'powell': 191,
#          'worth': 3591,
#          'mentioning': 43,
#          'twice': 1092,
#          'found': 2183,
#          'quite': 2403,
#          'tasty': 3460,
#          'favorite': 4758,
#          'dishes': 2280,
#          'sesame': 263,
#          'chicken': 12767,
#          'sweet': 3621,
#          'sour': 780,
#          'pork': 2367,
#          'started': 1430,
#          'delivery': 1109,
#          'best': 9066,
#          'boyfriend': 881,
#          'stopped': 1525,
#          'dinner': 5269,
#          'first': 7474,
#          'night': 5645,
#          'driving': 311,
#          'across': 860,
#          'country': 353,
#          'california': 254,
#          'made': 6349,
#          'us': 9304,
#          'vegan': 839,
#          'everything': 5298,
#          'soo': 57,
#          'amazing': 6679,
#          'converted': 26,
#          'meat': 3600,
#          'eater': 181,
#          'instantly': 78,
#          'veganism': 1,
#          'pushed': 83,
#          'vegetarianism': 3,
#          'still': 4867,
#          'crave': 171,
#          'ice': 1456,
#          'cream': 2007,
#          'treat': 615,
#          'main': 1043,
#          'street': 1587,
#          'options': 2891,
#          'even': 8101,
#          'sandwiches': 1367,
#          'knew': 787,
#          'appreciated': 346,
#          'large': 2922,
#          'plexiglass': 10,
#          'near': 903,
#          'register': 382,
#          'keep': 1587,
#          'safe': 272,
#          'outdoor': 585,
#          'order': 11323,
#          'pick': 1550,
#          'prefer': 522,
#          'get': 15601,
#          'treats': 158,
#          'day': 4080,
#          "i'": 22989,
#          'come': 6163,
#          '8': 1417,
#          'scoop': 126,
#          'challegenge': 1,
#          'went': 6734,
#          'lunch': 4984,
#          'chips': 1928,
#          'salsa': 1117,
#          'corn': 934,
#          'enchiladas': 131,
#          'looked': 2048,
#          'small': 4302,
#          'filling': 851,
#          'servant': 2,
#          'friendly': 6832,
#          'efficient': 373,
#          "shorty'": 9,
#          'expanded': 63,
#          'delaware': 107,
#          'enjoyed': 2581,
#          'carryout': 257,
#          'week': 2017,
#          'pizza': 8414,
#          'wings': 2424,
#          'subs': 379,
#          'last': 3712,
#          'extended': 48,
#          'family': 2490,
#          'two': 5492,
#          'extra': 1783,
#          'italian': 1447,
#          'sub': 865,
#          'promised': 118,
#          '20': 1836,
#          'mins': 479,
#          'ready': 1275,
#          'time': 16175,
#          'home': 3153,
#          'hot': 5049,
#          'fresh': 5803,
#          'staff': 7172,
#          'always': 8671,
#          'greet': 151,
#          'arrive': 354,
#          'pickup': 257,
#          'sit': 1735,
#          'highly': 2151,
#          'recommend': 4554,
#          'mvp': 3,
#          'supreme': 81,
#          'pepperoni': 718,
#          "pizza'": 48,
#          'relatively': 231,
#          'thin': 761,
#          'wafer': 6,
#          'new': 4497,
#          'york': 305,
#          'style': 1618,
#          'covered': 480,
#          'cheese': 7381,
#          'toppings': 1272,
#          '8in': 1,
#          'full': 2768,
#          'inside': 2699,
#          'cool': 1866,
#          "don'": 8471,
#          'bar': 8035,
#          'area': 4385,
#          'seats': 433,
#          '12': 880,
#          '15': 1674,
#          'tables': 2585,
#          'patio': 2341,
#          'bartenders': 736,
#          'plenty': 1468,
#          'front': 1652,
#          'plaza': 105,
#          'udf': 9,
#          'opposite': 95,
#          'end': 1461,
#          'thanks': 679,
#          'golden': 158,
#          'china': 132,
#          'one': 15520,
#          'daughters': 74,
#          'picked': 507,
#          'takeout': 529,
#          'hilliard': 282,
#          'pleased': 484,
#          'choice': 1208,
#          'quality': 3549,
#          'high': 2769,
#          'profiles': 28,
#          'portion': 1510,
#          'point': 1792,
#          'agreeable': 3,
#          'kung': 94,
#          'pao': 74,
#          'egg': 1935,
#          'rolls': 1646,
#          'crab': 1230,
#          'rangoons': 57,
#          'steamed': 277,
#          'dumplings': 520,
#          'stood': 325,
#          'rest': 821,
#          'excellent': 3860,
#          'texture': 524,
#          'amount': 1528,
#          'truly': 680,
#          'columbus': 6698,
#          'find': 3266,
#          'shrimp': 2460,
#          'frozen': 512,
#          'eddies': 9,
#          'bland': 1064,
#          'steak': 2783,
#          'bourbon': 377,
#          'ribeye': 182,
#          'fatty': 148,
#          'cut': 1028,
#          'correctly': 168,
#          'cake': 1139,
#          'clearly': 547,
#          'well': 9260,
#          'without': 2232,
#          'drinks': 5494,
#          'total': 537,
#          'bill': 1000,
#          '95': 187,
#          '1': 2931,
#          'person': 1512,
#          'anything': 2405,
#          'watering': 151,
#          'let': 1862,
#          'especially': 1930,
#          'attraction': 30,
#          'obviously': 503,
#          'tea': 1890,
#          'okonomiyaki': 5,
#          'though': 4078,
#          'totally': 854,
#          'authentic': 1232,
#          'needed': 1150,
#          'could': 6411,
#          'bring': 1464,
#          'young': 558,
#          'children': 210,
#          'meet': 412,
#          'state': 315,
#          'completely': 865,
#          'incorrect': 119,
#          'items': 2101,
#          'left': 2393,
#          'hostess': 792,
#          'combo': 631,
#          'package': 66,
#          'saved': 147,
#          'money': 1391,
#          'politely': 69,
#          'counter': 1286,
#          'explain': 270,
#          'issue': 787,
#          'asked': 3574,
#          'receipt': 222,
#          'never': 6772,
#          'gave': 1870,
#          'trying': 1849,
#          'things': 2966,
#          'cared': 78,
#          '2': 5058,
#          'different': 3103,
#          'employees': 1146,
#          'manager': 2320,
#          'forth': 81,
#          'printed': 42,
#          'original': 420,
#          'agreed': 202,
#          'void': 28,
#          'recharged': 2,
#          'offering': 280,
#          'considerable': 6,
#          'change': 762,
#          'cost': 612,
#          "wasn'": 4390,
#          'help': 968,
#          'group': 1649,
#          'says': 580,
#          'training': 171,
#          'customers': 1336,
#          'sure': 4728,
#          'job': 1012,
#          'experience': 6129,
#          "won'": 1792,
#          'particular': 397,
#          'anyone': 1202,
#          'unhappy': 62,
#          'fun': 2356,
#          'kids': 1448,
#          'neighborhood': 769,
#          'al': 721,
#          'happy': 4214,
#          'hour': 3630,
#          'bartender': 1248,
#          'awesome': 3353,
#          'limited': 685,
#          'menu': 9341,
#          'pricing': 279,
#          'eclectic': 137,
#          'mixed': 737,
#          'crowd': 717,
#          'nots': 1,
#          'welcoming': 526,
#          'folks': 472,
#          'bigger': 350,
#          'although': 1387,
#          'expect': 1442,
#          'wait': 5896,
#          'second': 1686,
#          'walk': 1358,
#          'friend': 2471,
#          'impressed': 1402,
#          'loved': 2815,
#          'drink': 4107,
#          'stylized': 3,
#          'ikea': 16,
#          'three': 1978,
#          'star': 1912,
#          'show': 711,
#          'carrot': 223,
#          "can'": 4211,
#          'enough': 3292,
#          'thinking': 471,
#          'vegetarian': 988,
#          'every': 4063,
#          'im': 205,
#          'disappointed': 2477,
#          'maybe': 2540,
#          'little': 7896,
#          'pricier': 116,
#          'truck': 669,
#          'consistently': 502,
#          'serves': 242,
#          'tacos': 2708,
#          'taste': 3516,
#          '75': 192,
#          'value': 659,
#          'nothing': 2893,
#          'fancy': 550,
#          'stuff': 966,
#          'quesadillas': 109,
#          'tortas': 56,
#          'jaritos': 1,
#          'soda': 336,
#          'prices': 2918,
#          'coming': 2296,
#          'year': 1189,
#          'greek': 1126,
#          'fries': 4535,
#          'really': 12947,
#          'overlooked': 51,
#          'tenders': 220,
#          'brussels': 218,
#          'sprouts': 531,
#          'yum': 965,
#          'cheeseburger': 262,
#          'son': 556,
#          'bacon': 2055,
#          'stir': 86,
#          'sandwich': 4520,
#          'burger': 3557,
#          'greasy': 759,
#          'wrapping': 26,
#          'translucent': 4,
#          '3': 4082,
#          'tablespoons': 9,
#          'mayo': 374,
#          'ketchup': 236,
#          'mixture': 97,
#          'dripping': 58,
#          'worst': 1222,
#          'ever': 4951,
#          'wendys': 23,
#          'general': 729,
#          'cannot': 647,
#          'brag': 33,
#          'believe': 1029,
#          'sushi': 2064,
#          'mean': 782,
#          'clean': 2442,
#          'classy': 319,
#          'absolutely': 2159,
#          'impeccable': 145,
#          'wish': 1501,
#          'cincinnati': 171,
#          'seems': 1424,
#          'impossible': 153,
#          'figure': 273,
#          "there'": 1904,
#          'lot': 3900,
#          'behind': 954,
#          'building': 686,
#          'figured': 286,
#          'since': 3969,
#          'heading': 144,
#          'give': 4010,
#          'spot': 2939,
#          'another': 3845,
#          'chance': 701,
#          'around': 4433,
#          'better': 5633,
#          'moment': 261,
#          'walked': 1463,
#          'inviting': 277,
#          'harder': 43,
#          'leave': 1211,
#          'comfortable': 634,
#          'mind': 1023,
#          'bumps': 16,
#          'disappoint': 510,
#          'music': 1317,
#          'sounded': 265,
#          'blaring': 21,
#          'took': 3813,
#          'eye': 332,
#          'candy': 92,
#          'changed': 518,
#          'way': 5023,
#          'view': 480,
#          'form': 137,
#          'previous': 332,
#          'review': 2068,
#          'seemed': 1814,
#          'chore': 12,
#          'makes': 1700,
#          'look': 1891,
#          'forward': 910,
#          'next': 3837,
#          'cafe': 830,
#          'kind': 2604,
#          'average': 1297,
#          'strip': 574,
#          'mall': 476,
#          'course': 1405,
#          'interior': 642,
#          'seating': 1953,
#          "isn'": 1762,
#          'many': 3971,
#          'people': 6092,
#          'may': 1700,
#          'feel': 2879,
#          'actually': 2294,
#          'staying': 187,
#          'looks': 993,
#          'fine': 1535,
#          'dining': 2404,
#          'liquor': 214,
#          "doesn'": 1583,
#          'japanese': 232,
#          'hunan': 73,
#          'bean': 543,
#          'curd': 28,
#          '9': 960,
#          'regular': 1340,
#          'proud': 74,
#          'room': 2016,
#          'big': 3124,
#          'portions': 1642,
#          'joined': 59,
#          'yelp': 1111,
#          'goremade': 16,
#          'block': 186,
#          'pie': 930,
#          'wise': 217,
#          'far': 1883,
#          'beats': 73,
#          'harvest': 86,
#          'easily': 665,
#          'soul': 155,
#          'confidence': 26,
#          'dough': 297,
#          'paulie': 4,
#          "gee'": 2,
#          "hasn'": 176,
#          'yet': 1494,
#          'admittedly': 52,
#          'partisan': 1,
#          'opinion': 607,
#          'warm': 1903,
#          'unfussy': 1,
#          'woodwork': 8,
#          'lovingly': 8,
#          'handmade': 48,
#          'ingredients': 1323,
#          'local': 1888,
#          'want': 4671,
#          "they'": 2338,
#          'chanterelles': 1,
#          'arugula': 148,
#          'cardamom': 8,
#          'tulsi': 1,
#          'foraged': 1,
#          'sown': 1,
#          'brings': 207,
#          'together': 1023,
#          'earth': 154,
#          'godsend': 6,
#          "we'": 2509,
#          'pros': 128,
#          'trendy': 304,
#          'decor': 1423,
#          'check': 2591,
#          'comes': 1714,
#          'book': 345,
#          'write': 556,
#          'thought': 2330,
#          'okay': 1512,
#          'stuffed': 616,
#          'ravioli': 228,
#          'dish': 2797,
#          'lacked': 242,
#          'husband': 2549,
#          'personal': 418,
#          'preference': 117,
#          'cons': 121,
#          'close': 1667,
#          'awkward': 187,
#          'bc': 194,
#          'hear': 590,
#          'conversation': 504,
#          'right': 4797,
#          'glass': 1038,
#          'wine': 2873,
#          'noticing': 37,
#          'likely': 415,
#          'restaurants': 2363,
#          'creative': 284,
#          'blending': 7,
#          'classic': 555,
#          'adventurous': 118,
#          'tastes': 796,
#          'crafted': 105,
#          'cocktails': 1277,
#          'often': 1463,
#          'spirits': 89,
#          'gem': 664,
#          'visiting': 788,
#          'nyc': 168,
#          'lived': 555,
#          'bagels': 276,
#          'wet': 130,
#          'nap': 34,
#          'hershey': 9,
#          'kiss': 29,
#          'exciting': 142,
#          'surprise': 472,
#          'killing': 35,
#          'guys': 711,
#          'location': 5111,
#          'black': 938,
#          'burrito': 989,
#          'guy': 1109,
#          'personally': 400,
#          'nasty': 238,
#          'laugh': 56,
#          'luck': 240,
#          'lol': 506,
#          'fast': 2683,
#          'taco': 1508,
#          'bell': 360,
#          'grape': 123,
#          'leaves': 232,
#          'put': 2070,
#          'facehole': 1,
#          'mujadara': 11,
#          'salad': 5886,
#          'lettuce': 891,
#          'lentils': 101,
#          'rice': 3109,
#          'weird': 552,
#          'poured': 139,
#          'house': 2382,
#          'dressing': 981,
#          'tied': 37,
#          'flavors': 1349,
#          'perfectly': 1811,
#          'expectations': 513,
#          'guess': 910,
#          'expecting': 561,
#          'something': 4151,
#          'jimmy': 78,
#          "john'": 41,
#          'wife': 1971,
#          'spring': 507,
#          'sick': 254,
#          'subway': 127,
#          'joint': 620,
#          'argue': 71,
#          'severely': 48,
#          'limits': 25,
#          'eat': 5546,
#          'handed': 197,
#          'seek': 52,
#          'helpful': 1263,
#          'lots': 1499,
#          'questions': 406,
#          'shop': 906,
#          'certain': 295,
#          'protocol': 15,
#          'handle': 208,
#          'ordering': 1632,
#          'driven': 104,
#          "haven'": 1056,
#          'craving': 615,
#          'stick': 501,
#          'suppose': 170,
#          'willing': 345,
#          'strong': 531,
#          'reason': 1291,
#          'ie': 27,
#          'someone': 1637,
#          'wanted': 2901,
#          'girlfriend': 413,
#          'mine': 688,
#          'arranged': 27,
#          'hang': 394,
#          'derby': 11,
#          'surprising': 110,
#          'ways': 160,
#          'flipped': 26,
#          'years': 2388,
#          'hopefully': 275,
#          'awhile': 425,
#          'mediterranean': 544,
#          'sunset': 28,
#          'holy': 356,
#          'cow': 68,
#          'calamari': 709,
#          'divine': 148,
#          'kabob': 111,
#          'share': 760,
#          'pleasantly': 375,
#          'surprised': 963,
#          'decorated': 219,
#          'event': 546,
#          'opposed': 88,
#          'self': 301,
#          'serve': 1246,
#          'veggies': 1081,
#          'super': 3517,
#          'jay': 11,
#          'positive': 337,
#          'know': 4816,
#          'remembers': 33,
#          'name': 1373,
#          'normally': 571,
#          '5': 4844,
#          'times': 4526,
#          'foods': 608,
#          'firebirds': 91,
#          'buying': 149,
#          'pizzas': 794,
#          "joe'": 56,
#          'tommy': 16,
#          'bought': 328,
#          '30th': 25,
#          'eating': 2226,
#          'slices': 515,
#          'realized': 322,
#          'accustomed': 36,
#          'called': 1583,
#          'spoke': 203,
#          'owner': 1362,
#          'less': 1539,
#          'laudatory': 1,
#          'told': 2945,
#          'return': 1582,
#          'per': 438,
#          'instructions': 52,
#          'received': 990,
#          'replacement': 72,
#          'prepared': 1110,
#          'speak': 405,
#          'frowned': 8,
#          'frightening': 2,
#          'angrily': 13,
#          'manner': 137,
#          'encounter': 45,
#          'unprofessional': 136,
#          'extremely': 1459,
#          'unnerving': 1,
#          'thoughts': 61,
#          'unspeakable': 2,
#          'racing': 16,
#          'desired': 172,
#          'trash': 193,
#          'vowed': 10,
#          'business': 1757,
#          'wrong': 1907,
#          'sorry': 682,
#          'inconvenience': 85,
#          'confused': 225,
#          'similar': 466,
#          'hope': 846,
#          'asian': 697,
#          'inspired': 111,
#          'rangoon': 303,
#          'lemongrass': 224,
#          'phenomenal': 516,
#          'waiters': 250,
#          'chic': 75,
#          'elevator': 179,
#          'tighten': 3,
#          'game': 1127,
#          'enjoying': 300,
#          'interesting': 779,
#          'beers': 1173,
#          'unfortunately': 871,
#          'par': 347,
#          'bagged': 33,
#          'least': 1851,
#          'shriveled': 9,
#          'pieces': 819,
#          'bottom': 429,
#          'bag': 601,
#          'likewise': 18,
#          'entrees': 954,
#          'failed': 114,
#          'live': 1385,
#          'potential': 148,
#          'came': 7304,
#          'breast': 279,
#          'breading': 215,
#          'thick': 704,
#          'heavy': 477,
#          'curiously': 4,
#          'restricted': 10,
#          'arrived': 1566,
#          'p': 232,
#          'standout': 54,
#          'beer': 3563,
#          'signature': 274,
#          'ale': 216,
#          'barleywine': 1,
#          'passable': 28,
#          'whole': 1649,
#          'kept': 873,
#          'imagining': 9,
#          'gordon': 22,
#          'ramsay': 8,
#          'bursting': 43,
#          'revamping': 4,
#          'whipping': 4,
#          'kitchen': 1411,
#          'shape': 69,
#          'future': 495,
#          'visits': 356,
#          'skipping': 17,
#          'hr': 43,
#          '4th': 130,
#          'july': 75,
#          'weekend': 1011,
#          'finally': 2001,
#          'eagle': 327,
#          'tonight': 1012,
#          'short': 2189,
#          'north': 1952,
#          'born': 49,
#          'tennessee': 16,
#          'southern': 305,
#          'girl': 642,
#          'heart': 364,
#          'comfort': 348,
#          'satisfied': 380,
#          '4': 3376,
#          'fried': 3482,
#          'among': 228,
#          'four': 997,
#          'collards': 40,
#          'spoon': 215,
#          'bread': 3666,
#          'biscuits': 471,
#          'mac': 1974,
#          'n': 762,
#          'succotash': 32,
#          'cant': 183,
#          'modern': 423,
#          'cover': 227,
#          'barely': 538,
#          'move': 408,
#          'summer': 645,
#          'u': 225,
#          'crowded': 852,
#          'anybody': 71,
#          '11': 591,
#          'cheap': 1067,
#          'warned': 122,
#          'shot': 446,
#          'tall': 116,
#          'pint': 165,
#          'planning': 189,
#          'accordingly': 57,
#          'burgers': 1172,
#          'brats': 15,
#          'dogs': 190,
#          'wha': 5,
#          'friends': 3146,
#          'ohio': 1274,
#          'theater': 163,
#          'pearl': 352,
#          'exceptional': 386,
#          'craft': 425,
#          'selection': 2581,
#          'server': 4735,
#          'answering': 59,
#          'appetizers': 1194,
#          'jalapeno': 161,
#          'kick': 457,
#          'jalapenos': 90,
#          'sausage': 1055,
#          'sampler': 264,
#          'ok': 2453,
#          'ladies': 213,
#          'split': 779,
#          'grits': 273,
#          'cinnamon': 641,
#          'role': 37,
#          'meals': 1249,
#          'ribs': 883,
#          'memorable': 193,
#          'regularly': 181,
#          'beat': 482,
#          'getting': 2101,
#          '7': 1371,
#          'crispy': 1599,
#          'honey': 619,
#          'red': 1584,
#          'sauce': 7141,
#          'die': 574,
#          'sides': 1316,
#          'homemade': 813,
#          'berry': 85,
#          'jam': 269,
#          'whipped': 159,
#          'butter': 1059,
#          'husbands': 84,
#          'aioli': 176,
#          'maple': 203,
#          'infused': 70,
#          'cornbread': 224,
#          'take': 4530,
#          'depending': 190,
#          'floors': 126,
#          'picnic': 129,
#          'floor': 562,
#          'weeks': 542,
#          'ago': 1191,
#          'sat': 1785,
#          'available': 967,
#          'covid': 401,
#          'wear': 159,
#          'masks': 134,
#          'bumped': 27,
#          'fall': 279,
#          'seated': 1928,
#          'guests': 396,
#          'shoulder': 62,
#          'else': 2184,
#          'add': 1243,
#          'hooks': 9,
#          'bags': 126,
#          'set': 793,
#          'cleanest': 31,
#          'old': 2346,
#          'loves': 386,
#          'kid': 332,
#          'boosters': 2,
#          'booths': 281,
#          'slide': 44,
#          'sits': 73,
#          'knees': 16,
#          'typically': 444,
#          'splitting': 72,
#          'huge': 2409,
#          'fan': 1566,
#          'adults': 173,
#          'seem': 1131,
#          '10': 3631,
#          'timely': 191,
#          'servers': 1193,
#          'usually': 2341,
#          'multiple': 612,
#          'quick': 2156,
#          'bathrooms': 293,
#          'takes': 579,
#          'minute': 688,
#          'meter': 61,
#          'followed': 208,
#          'baked': 961,
#          'goods': 257,
#          'satanic': 2,
#          'sammiches': 6,
#          "freakin'": 27,
#          'opening': 410,
#          'nearer': 5,
#          'huzzah': 3,
#          'reservations': 749,
#          'evening': 1415,
#          'minutes': 5034,
#          'early': 1039,
#          'heather': 13,
#          'fantastic': 2487,
#          'tuna': 640,
#          'appetizer': 1713,
#          'mahi': 127,
#          'linguini': 28,
#          'meal': 5742,
#          'served': 2551,
#          'piping': 156,
#          'seven': 133,
#          'middle': 664,
#          'juicy': 670,
#          'horseradish': 112,
#          'mash': 77,
#          'hole': 261,
#          'wall': 632,
#          'special': 3018,
#          'roll': 1608,
#          'probably': 2786,
#          'hours': 1354,
#          'waste': 387,
#          'worked': 509,
#          'interest': 81,
#          'vibe': 896,
#          ...})

# %% [markdown]
# #### Define max number of words in a sequence
# * Setting this max number is important because we need to define a maximum sequence length that we can set to a number we pick
# * Note: Depending on the text, it is better to set this number high
# * (ex: Tweet - it is better to set this number to a high number between 50-70)
# * (ex: bigger text - you can set it to 200 or more)
# * In our trial, we're just going to start off small with 50 words
#
# The reason we need to define the sequence length is because when we use it with Tensorflow, we're going to need the same number of words/sequence length for each sequence.
#
# We won't be able to have sequences of different lengths. We need to map them to the same sequence size.

# %%
num_words = len(counter)

# Max number of words in a sequence
max_length = 50

# %% [markdown]
# #### Use the Tokenizer Class
#
# The next thing we need to use is the Tokenizer class from keras to tokenize the train sentences

# %%
# import the tokenizer from keras preprocessing 
from tensorflow.keras.preprocessing.text import Tokenizer

# %%
# Fit the tokenizer onto the train sentences 
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(X_train2)

# %%
# Pulls the word index from the tokenizer 
word_index = tokenizer.word_index

# This is an attribute of the tokenizer
# The attribute is a dictionary where
# key = actual word 
# value = the number that will now represent that word

# %%
word_index
# Out:
# {'food': 1,
#  'good': 2,
#  'place': 3,
#  'great': 4,
#  "i'": 5,
#  'like': 6,
#  'service': 7,
#  'time': 8,
#  "it'": 9,
#  'get': 10,
#  'one': 11,
#  'back': 12,
#  'go': 13,
#  'really': 14,
#  'would': 15,
#  'chicken': 16,
#  'also': 17,
#  'order': 18,
#  'got': 19,
#  'ordered': 20,
#  'restaurant': 21,
#  'menu': 22,
#  'us': 23,
#  'delicious': 24,
#  'well': 25,
#  'best': 26,
#  'nice': 27,
#  'love': 28,
#  'always': 29,
#  "don'": 30,
#  'pizza': 31,
#  'try': 32,
#  'even': 33,
#  'bar': 34,
#  'little': 35,
#  'first': 36,
#  'cheese': 37,
#  'came': 38,
#  'staff': 39,
#  'definitely': 40,
#  'sauce': 41,
#  'pretty': 42,
#  'friendly': 43,
#  "didn'": 44,
#  'never': 45,
#  'went': 46,
#  'columbus': 47,
#  'amazing': 48,
#  'much': 49,
#  'could': 50,
#  'made': 51,
#  'come': 52,
#  'experience': 53,
#  'people': 54,
#  'wait': 55,
#  'salad': 56,
#  'fresh': 57,
#  'meal': 58,
#  'table': 59,
#  'night': 60,
#  'better': 61,
#  'make': 62,
#  'eat': 63,
#  'drinks': 64,
#  'two': 65,
#  'everything': 66,
#  'dinner': 67,
#  "you'": 68,
#  'location': 69,
#  '2': 70,
#  'hot': 71,
#  'minutes': 72,
#  'way': 73,
#  'lunch': 74,
#  'ever': 75,
#  'think': 76,
#  'still': 77,
#  '5': 78,
#  'going': 79,
#  'said': 80,
#  'know': 81,
#  'right': 82,
#  'favorite': 83,
#  'server': 84,
#  'sure': 85,
#  'want': 86,
#  'say': 87,
#  'side': 88,
#  'recommend': 89,
#  'fries': 90,
#  'take': 91,
#  'times': 92,
#  'sandwich': 93,
#  'new': 94,
#  'bit': 95,
#  'around': 96,
#  "wasn'": 97,
#  'area': 98,
#  'tried': 99,
#  'small': 100,
#  'atmosphere': 101,
#  'happy': 102,
#  "can'": 103,
#  'something': 104,
#  'drink': 105,
#  '3': 106,
#  'day': 107,
#  'though': 108,
#  'every': 109,
#  'flavor': 110,
#  'bad': 111,
#  'give': 112,
#  'many': 113,
#  'since': 114,
#  'lot': 115,
#  'excellent': 116,
#  'another': 117,
#  'next': 118,
#  'took': 119,
#  'last': 120,
#  'bread': 121,
#  'long': 122,
#  '10': 123,
#  'hour': 124,
#  'sweet': 125,
#  'price': 126,
#  'meat': 127,
#  'worth': 128,
#  'asked': 129,
#  'beer': 130,
#  'burger': 131,
#  'see': 132,
#  'quality': 133,
#  'super': 134,
#  'taste': 135,
#  'visit': 136,
#  'fried': 137,
#  'top': 138,
#  'tasty': 139,
#  'perfect': 140,
#  'spicy': 141,
#  '4': 142,
#  'awesome': 143,
#  'enough': 144,
#  'find': 145,
#  'coffee': 146,
#  'thing': 147,
#  'home': 148,
#  'friends': 149,
#  'big': 150,
#  'rice': 151,
#  'different': 152,
#  'overall': 153,
#  'busy': 154,
#  'breakfast': 155,
#  'special': 156,
#  'things': 157,
#  'told': 158,
#  'spot': 159,
#  '1': 160,
#  "that'": 161,
#  'large': 162,
#  'prices': 163,
#  'soup': 164,
#  'wanted': 165,
#  'however': 166,
#  'nothing': 167,
#  'options': 168,
#  'looking': 169,
#  'cooked': 170,
#  'feel': 171,
#  'wine': 172,
#  'places': 173,
#  'stars': 174,
#  'loved': 175,
#  'dish': 176,
#  'half': 177,
#  'probably': 178,
#  'steak': 179,
#  'free': 180,
#  'high': 181,
#  'full': 182,
#  'tacos': 183,
#  'inside': 184,
#  'fast': 185,
#  'kind': 186,
#  'check': 187,
#  'tables': 188,
#  'enjoyed': 189,
#  'selection': 190,
#  'parking': 191,
#  'served': 192,
#  'husband': 193,
#  'town': 194,
#  'maybe': 195,
#  'away': 196,
#  "we'": 197,
#  'family': 198,
#  'fantastic': 199,
#  'disappointed': 200,
#  'friend': 201,
#  'shrimp': 202,
#  'line': 203,
#  'ok': 204,
#  'clean': 205,
#  'wings': 206,
#  'tasted': 207,
#  'cold': 208,
#  'huge': 209,
#  'anything': 210,
#  'dining': 211,
#  'quite': 212,
#  'left': 213,
#  'work': 214,
#  'years': 215,
#  'house': 216,
#  'pork': 217,
#  'restaurants': 218,
#  'fun': 219,
#  'need': 220,
#  'old': 221,
#  'patio': 222,
#  'usually': 223,
#  "they'": 224,
#  'waitress': 225,
#  'ask': 226,
#  'thought': 227,
#  'manager': 228,
#  'everyone': 229,
#  'coming': 230,
#  'actually': 231,
#  'dishes': 232,
#  'customer': 233,
#  'open': 234,
#  'without': 235,
#  'eating': 236,
#  'decided': 237,
#  'fish': 238,
#  'wonderful': 239,
#  'short': 240,
#  'else': 241,
#  'found': 242,
#  'enjoy': 243,
#  'absolutely': 244,
#  'quick': 245,
#  'highly': 246,
#  'almost': 247,
#  'hard': 248,
#  'outside': 249,
#  'items': 250,
#  'getting': 251,
#  'put': 252,
#  'review': 253,
#  'sushi': 254,
#  'bacon': 255,
#  'looked': 256,
#  'decent': 257,
#  'beef': 258,
#  'week': 259,
#  'room': 260,
#  'cream': 261,
#  'finally': 262,
#  'three': 263,
#  'mac': 264,
#  'wife': 265,
#  'seating': 266,
#  'north': 267,
#  'couple': 268,
#  'dessert': 269,
#  'egg': 270,
#  'especially': 271,
#  'chips': 272,
#  'seated': 273,
#  'several': 274,
#  'star': 275,
#  'wrong': 276,
#  "there'": 277,
#  'warm': 278,
#  'drive': 279,
#  'look': 280,
#  'tea': 281,
#  'local': 282,
#  'used': 283,
#  'far': 284,
#  'gave': 285,
#  'waiting': 286,
#  'cool': 287,
#  'let': 288,
#  'least': 289,
#  'trying': 290,
#  '20': 291,
#  'stop': 292,
#  '6': 293,
#  '30': 294,
#  'seemed': 295,
#  'perfectly': 296,
#  'today': 297,
#  'brought': 298,
#  'point': 299,
#  "won'": 300,
#  'must': 301,
#  'sat': 302,
#  'extra': 303,
#  'done': 304,
#  "isn'": 305,
#  "couldn'": 306,
#  'business': 307,
#  'tell': 308,
#  'attentive': 309,
#  'waiter': 310,
#  'bowl': 311,
#  'sit': 312,
#  'chinese': 313,
#  'comes': 314,
#  'appetizer': 315,
#  'makes': 316,
#  'may': 317,
#  'brunch': 318,
#  'second': 319,
#  '15': 320,
#  'potatoes': 321,
#  'reviews': 322,
#  'close': 323,
#  'waited': 324,
#  'front': 325,
#  'group': 326,
#  'whole': 327,
#  'rolls': 328,
#  'oh': 329,
#  'portions': 330,
#  'someone': 331,
#  'ordering': 332,
#  'part': 333,
#  'style': 334,
#  'instead': 335,
#  'roll': 336,
#  'crispy': 337,
#  'street': 338,
#  'keep': 339,
#  'red': 340,
#  "doesn'": 341,
#  'called': 342,
#  'return': 343,
#  'flavorful': 344,
#  'arrived': 345,
#  'fan': 346,
#  'pick': 347,
#  'either': 348,
#  'water': 349,
#  'less': 350,
#  'size': 351,
#  'door': 352,
#  'fine': 353,
#  'liked': 354,
#  'amount': 355,
#  'stopped': 356,
#  'ate': 357,
#  'party': 358,
#  'plate': 359,
#  'person': 360,
#  'okay': 361,
#  'portion': 362,
#  'taco': 363,
#  'slow': 364,
#  'use': 365,
#  'wish': 366,
#  'lots': 367,
#  'might': 368,
#  'yet': 369,
#  'felt': 370,
#  'crust': 371,
#  'orders': 372,
#  'mexican': 373,
#  'city': 374,
#  'able': 375,
#  'plenty': 376,
#  'bring': 377,
#  'walked': 378,
#  'often': 379,
#  'saturday': 380,
#  'end': 381,
#  'space': 382,
#  'extremely': 383,
#  'ice': 384,
#  'kids': 385,
#  'italian': 386,
#  'later': 387,
#  'expect': 388,
#  'care': 389,
#  'quickly': 390,
#  'started': 391,
#  'seems': 392,
#  'decor': 393,
#  '8': 394,
#  'evening': 395,
#  'thai': 396,
#  'kitchen': 397,
#  'course': 398,
#  'impressed': 399,
#  'real': 400,
#  'money': 401,
#  'white': 402,
#  'although': 403,
#  'live': 404,
#  'dry': 405,
#  'french': 406,
#  'name': 407,
#  '7': 408,
#  'sandwiches': 409,
#  'owner': 410,
#  'soon': 411,
#  'market': 412,
#  'walk': 413,
#  'hours': 414,
#  'flavors': 415,
#  'regular': 416,
#  'customers': 417,
#  'yes': 418,
#  'bbq': 419,
#  'start': 420,
#  'pasta': 421,
#  'ingredients': 422,
#  'music': 423,
#  'offer': 424,
#  'sides': 425,
#  'call': 426,
#  'making': 427,
#  "wouldn'": 428,
#  'potato': 429,
#  'average': 430,
#  'eggs': 431,
#  'reason': 432,
#  'variety': 433,
#  'counter': 434,
#  'store': 435,
#  'cocktails': 436,
#  'ohio': 437,
#  'ready': 438,
#  'toppings': 439,
#  'grilled': 440,
#  'helpful': 441,
#  'salmon': 442,
#  'beans': 443,
#  'meals': 444,
#  'bartender': 445,
#  'sunday': 446,
#  'serve': 447,
#  'add': 448,
#  'authentic': 449,
#  'crab': 450,
#  'pay': 451,
#  'past': 452,
#  'worst': 453,
#  'reservation': 454,
#  'leave': 455,
#  'ended': 456,
#  'choice': 457,
#  'beautiful': 458,
#  'anyone': 459,
#  'bite': 460,
#  'birthday': 461,
#  'sitting': 462,
#  'appetizers': 463,
#  'servers': 464,
#  'ago': 465,
#  'year': 466,
#  'terrible': 467,
#  'already': 468,
#  'beers': 469,
#  'burgers': 470,
#  'unique': 471,
#  'list': 472,
#  'saw': 473,
#  'plus': 474,
#  'light': 475,
#  'option': 476,
#  'friday': 477,
#  'needed': 478,
#  'chocolate': 479,
#  'date': 480,
#  'ambiance': 481,
#  'employees': 482,
#  'deal': 483,
#  'glad': 484,
#  'yummy': 485,
#  'cake': 486,
#  'easy': 487,
#  'seem': 488,
#  'late': 489,
#  'game': 490,
#  'greek': 491,
#  'garlic': 492,
#  'chipotle': 493,
#  'working': 494,
#  'salsa': 495,
#  'tender': 496,
#  'heard': 497,
#  'yelp': 498,
#  'prepared': 499,
#  'delivery': 500,
#  'guy': 501,
#  'given': 502,
#  'priced': 503,
#  'packed': 504,
#  'twice': 505,
#  'gyro': 506,
#  'veggies': 507,
#  'green': 508,
#  'onion': 509,
#  'cheap': 510,
#  'eaten': 511,
#  'bland': 512,
#  'butter': 513,
#  'reasonable': 514,
#  "haven'": 515,
#  'sausage': 516,
#  'salads': 517,
#  'fact': 518,
#  'main': 519,
#  'rude': 520,
#  'early': 521,
#  'glass': 522,
#  'choose': 523,
#  'believe': 524,
#  'cut': 525,
#  '50': 526,
#  'tip': 527,
#  'expensive': 528,
#  'mind': 529,
#  'together': 530,
#  'five': 531,
#  'entire': 532,
#  'job': 533,
#  'tonight': 534,
#  'weekend': 535,
#  'days': 536,
#  'trip': 537,
#  'pho': 538,
#  'added': 539,
#  'others': 540,
#  'bill': 541,
#  'simple': 542,
#  'sauces': 543,
#  'four': 544,
#  'hit': 545,
#  'sometimes': 546,
#  'expected': 547,
#  'looks': 548,
#  'offered': 549,
#  'problem': 550,
#  'received': 551,
#  'burrito': 552,
#  'vegetarian': 553,
#  'gets': 554,
#  'dressing': 555,
#  'rather': 556,
#  'honestly': 557,
#  'lamb': 558,
#  'buffet': 559,
#  'choices': 560,
#  'help': 561,
#  'literally': 562,
#  'available': 563,
#  'stuff': 564,
#  'cocktail': 565,
#  'yum': 566,
#  'surprised': 567,
#  'along': 568,
#  'etc': 569,
#  'specials': 570,
#  'baked': 571,
#  '9': 572,
#  'medium': 573,
#  'excited': 574,
#  'behind': 575,
#  'entrees': 576,
#  'brisket': 577,
#  'toast': 578,
#  "weren'": 579,
#  'onions': 580,
#  'donuts': 581,
#  'downtown': 582,
#  'black': 583,
#  'seafood': 584,
#  'remember': 585,
#  'due': 586,
#  'corn': 587,
#  'wow': 588,
#  'thank': 589,
#  'solid': 590,
#  'loud': 591,
#  'pie': 592,
#  'pricey': 593,
#  'seriously': 594,
#  'run': 595,
#  'entree': 596,
#  'gone': 597,
#  'taking': 598,
#  'based': 599,
#  'outstanding': 600,
#  'forward': 601,
#  'guess': 602,
#  'shop': 603,
#  'near': 604,
#  'vibe': 605,
#  'casual': 606,
#  'pita': 607,
#  'lettuce': 608,
#  'please': 609,
#  'horrible': 610,
#  'ribs': 611,
#  'plates': 612,
#  'morning': 613,
#  'boyfriend': 614,
#  '12': 615,
#  'soft': 616,
#  'cup': 617,
#  'spice': 618,
#  'hummus': 619,
#  'kept': 620,
#  'seasoned': 621,
#  'tomato': 622,
#  'empty': 623,
#  'unfortunately': 624,
#  'opened': 625,
#  'sub': 626,
#  'completely': 627,
#  'chef': 628,
#  'type': 629,
#  'across': 630,
#  'needs': 631,
#  'life': 632,
#  'totally': 633,
#  'lobster': 634,
#  'crowded': 635,
#  'filling': 636,
#  'visited': 637,
#  'incredible': 638,
#  'understand': 639,
#  'hope': 640,
#  'seen': 641,
#  'recommended': 642,
#  'vegan': 643,
#  'immediately': 644,
#  'cafe': 645,
#  'seat': 646,
#  'serving': 647,
#  'paid': 648,
#  'hungry': 649,
#  'tasting': 650,
#  'rest': 651,
#  'pastor': 652,
#  'phone': 653,
#  'thru': 654,
#  'pieces': 655,
#  'veggie': 656,
#  'poor': 657,
#  'pleasant': 658,
#  'piece': 659,
#  'disappointing': 660,
#  'homemade': 661,
#  'hand': 662,
#  'salty': 663,
#  'level': 664,
#  'recently': 665,
#  'grab': 666,
#  'mouth': 667,
#  'establishment': 668,
#  'online': 669,
#  'tastes': 670,
#  'greeted': 671,
#  'hands': 672,
#  'pizzas': 673,
#  'set': 674,
#  'hostess': 675,
#  'cute': 676,
#  'visiting': 677,
#  'knew': 678,
#  'issue': 679,
#  'gluten': 680,
#  'mean': 681,
#  'watch': 682,
#  'dark': 683,
#  'sour': 684,
#  'chain': 685,
#  'interesting': 686,
#  'split': 687,
#  'standard': 688,
#  'man': 689,
#  'neighborhood': 690,
#  'games': 691,
#  'noodles': 692,
#  'filled': 693,
#  'change': 694,
#  'n': 695,
#  'thin': 696,
#  'share': 697,
#  'greasy': 698,
#  'dip': 699,
#  "aren'": 700,
#  'reservations': 701,
#  'giving': 702,
#  'mixed': 703,
#  'bartenders': 704,
#  'salt': 705,
#  'general': 706,
#  'world': 707,
#  'diner': 708,
#  'healthy': 709,
#  'heat': 710,
#  'miss': 711,
#  'slightly': 712,
#  'al': 713,
#  'pepper': 714,
#  'pepperoni': 715,
#  'dirty': 716,
#  'crowd': 717,
#  'peppers': 718,
#  'show': 719,
#  'guys': 720,
#  'mix': 721,
#  'calamari': 722,
#  'thick': 723,
#  'chance': 724,
#  'taken': 725,
#  'shared': 726,
#  'oil': 727,
#  'single': 728,
#  'asian': 729,
#  'carry': 730,
#  'walking': 731,
#  'ahead': 732,
#  'simply': 733,
#  'mine': 734,
#  'minute': 735,
#  'exactly': 736,
#  'card': 737,
#  'low': 738,
#  'typical': 739,
#  'building': 740,
#  'meats': 741,
#  'limited': 742,
#  'saying': 743,
#  'sorry': 744,
#  'cook': 745,
#  'truly': 746,
#  'thanks': 747,
#  'including': 748,
#  'indian': 749,
#  'falafel': 750,
#  'vegetables': 751,
#  'feeling': 752,
#  'management': 753,
#  'chili': 754,
#  'pad': 755,
#  'juicy': 756,
#  'fairly': 757,
#  'window': 758,
#  'truck': 759,
#  '45': 760,
#  'longer': 761,
#  'upon': 762,
#  'easily': 763,
#  'gem': 764,
#  'middle': 765,
#  'stay': 766,
#  'addition': 767,
#  'value': 768,
#  'notch': 769,
#  'bun': 770,
#  '25': 771,
#  'ranch': 772,
#  'lemon': 773,
#  'idea': 774,
#  'certainly': 775,
#  'moved': 776,
#  'cannot': 777,
#  'number': 778,
#  'summer': 779,
#  'pancakes': 780,
#  'head': 781,
#  'pulled': 782,
#  'interior': 783,
#  'girl': 784,
#  'cinnamon': 785,
#  'tuna': 786,
#  'creamy': 787,
#  'dine': 788,
#  'mostly': 789,
#  'mediocre': 790,
#  'traditional': 791,
#  'finish': 792,
#  'comfortable': 793,
#  'wall': 794,
#  'anywhere': 795,
#  'combo': 796,
#  'stand': 797,
#  'talk': 798,
#  'located': 799,
#  'bottle': 800,
#  'read': 801,
#  'noticed': 802,
#  'slaw': 803,
#  'item': 804,
#  'double': 805,
#  'months': 806,
#  'joint': 807,
#  'honey': 808,
#  'charge': 809,
#  'gotten': 810,
#  'overpriced': 811,
#  'stuffed': 812,
#  'treat': 813,
#  'craving': 814,
#  'generous': 815,
#  'afternoon': 816,
#  'easton': 817,
#  'cost': 818,
#  'multiple': 819,
#  'basically': 820,
#  'chose': 821,
#  'owners': 822,
#  'foods': 823,
#  'hotel': 824,
#  'cheesecake': 825,
#  'opinion': 826,
#  'anyway': 827,
#  'avocado': 828,
#  '00': 829,
#  'favorites': 830,
#  'goes': 831,
#  'bag': 832,
#  'buy': 833,
#  'filet': 834,
#  'lady': 835,
#  'checked': 836,
#  'note': 837,
#  'club': 838,
#  'mention': 839,
#  'awful': 840,
#  'sign': 841,
#  'complaint': 842,
#  'ones': 843,
#  '11': 844,
#  'finished': 845,
#  'hear': 846,
#  'usual': 847,
#  'spinach': 848,
#  'beyond': 849,
#  'banana': 850,
#  'forgot': 851,
#  'outdoor': 852,
#  'non': 853,
#  'closed': 854,
#  'within': 855,
#  'delivered': 856,
#  'cozy': 857,
#  'incredibly': 858,
#  'unless': 859,
#  'says': 860,
#  'slice': 861,
#  'crisp': 862,
#  'takes': 863,
#  'car': 864,
#  'whatever': 865,
#  'rare': 866,
#  'strip': 867,
#  'die': 868,
#  'attention': 869,
#  'environment': 870,
#  'normally': 871,
#  'play': 872,
#  'fair': 873,
#  'lovely': 874,
#  'brown': 875,
#  'oysters': 876,
#  'rib': 877,
#  'gravy': 878,
#  'curry': 879,
#  'perfection': 880,
#  'mom': 881,
#  'floor': 882,
#  'happened': 883,
#  'sort': 884,
#  'expecting': 885,
#  'young': 886,
#  'mushrooms': 887,
#  'paying': 888,
#  'son': 889,
#  'write': 890,
#  'crazy': 891,
#  'classic': 892,
#  'lived': 893,
#  'sad': 894,
#  '40': 895,
#  'weird': 896,
#  'wrap': 897,
#  'placed': 898,
#  'fancy': 899,
#  'case': 900,
#  'clearly': 901,
#  'event': 902,
#  'donut': 903,
#  'smaller': 904,
#  'mediterranean': 905,
#  'bean': 906,
#  'seasoning': 907,
#  'weeks': 908,
#  'returning': 909,
#  'somewhere': 910,
#  'pudding': 911,
#  'missing': 912,
#  'alone': 913,
#  'barely': 914,
#  'broth': 915,
#  'except': 916,
#  'total': 917,
#  'greens': 918,
#  'mashed': 919,
#  'touch': 920,
#  'locations': 921,
#  'spend': 922,
#  'forget': 923,
#  'sprouts': 924,
#  'strong': 925,
#  'tiny': 926,
#  'desserts': 927,
#  'w': 928,
#  'takeout': 929,
#  'roasted': 930,
#  'talking': 931,
#  'turned': 932,
#  'welcoming': 933,
#  'pickles': 934,
#  'american': 935,
#  'turkey': 936,
#  'texture': 937,
#  'nicely': 938,
#  'prefer': 939,
#  'kinda': 940,
#  'dumplings': 941,
#  'village': 942,
#  'true': 943,
#  'changed': 944,
#  'asking': 945,
#  'phenomenal': 946,
#  'slices': 947,
#  'lack': 948,
#  'expectations': 949,
#  'concept': 950,
#  'tofu': 951,
#  'frozen': 952,
#  'park': 953,
#  'disappoint': 954,
#  'rich': 955,
#  'worked': 956,
#  'matter': 957,
#  'rating': 958,
#  'bites': 959,
#  'picked': 960,
#  'spring': 961,
#  'knowledgeable': 962,
#  'lol': 963,
#  'plan': 964,
#  'blue': 965,
#  'conversation': 966,
#  'road': 967,
#  'obviously': 968,
#  'fabulous': 969,
#  'sugar': 970,
#  'consistently': 971,
#  'crunchy': 972,
#  'stick': 973,
#  'mentioned': 974,
#  'scallops': 975,
#  'normal': 976,
#  'polite': 977,
#  'hate': 978,
#  'future': 979,
#  'plain': 980,
#  'smoked': 981,
#  'month': 982,
#  'included': 983,
#  'raw': 984,
#  'box': 985,
#  'supposed': 986,
#  'corner': 987,
#  'playing': 988,
#  'suggest': 989,
#  'spots': 990,
#  'iced': 991,
#  'bagel': 992,
#  'tomatoes': 993,
#  'daughter': 994,
#  'pleased': 995,
#  'beat': 996,
#  'spent': 997,
#  'means': 998,
#  'none': 999,
#  'covered': 1000,
#  ...}

# %%
# Creates the sequences from our tokenizer, based on the indices from the word_index
train_sequences2 = tokenizer.texts_to_sequences(X_train2)

# %%
X_train2.values[0]
# Out:
# "looking breakfast place town try stumbled upon mccarthy' it' smaller sized resteraunt think make due space busy saturday afternoon expected got table pretty quickly ordered skillet scrambler pancake significant got eggs benedict skillet good however wouldn' call skillet like scrambled eggs minced meats side scalloped potatoes potatoes melt mouth good eggs cooked excellently toast brought delicious pancake superb size plate nice circumference also thicker pancake great tasted great said eggs benedict alright eggs slightly undercooked hollandaise alright didn' much flavor also would liked ham thicker piece ham instead shaved use overall price reasonable food good service nice throughout visit definitely going back"

# %%
train_sequences2[0]  # This sequence has 24 words
# Out:
# [169,
#  155,
#  3,
#  194,
#  32,
#  2364,
#  762,
#  14982,
#  9,
#  904,
#  1095,
#  12552,
#  76,
#  62,
#  586,
#  382,
#  154,
#  380,
#  816,
#  547,
#  19,
#  59,
#  42,
#  390,
#  20,
#  1877,
#  6031,
#  1954,
#  3800,
#  19,
#  431,
#  2321,
#  1877,
#  2,
#  166,
#  428,
#  426,
#  1877,
#  6,
#  2374,
#  431,
#  6425,
#  741,
#  88,
#  7868,
#  321,
#  321,
#  1289,
#  667,
#  2,
#  431,
#  170,
#  5401,
#  578,
#  298,
#  24,
#  1954,
#  1483,
#  351,
#  359,
#  27,
#  13593,
#  17,
#  2765,
#  1954,
#  4,
#  207,
#  4,
#  80,
#  431,
#  2321,
#  1462,
#  431,
#  712,
#  1646,
#  3834,
#  1462,
#  44,
#  49,
#  110,
#  17,
#  15,
#  354,
#  1210,
#  2765,
#  659,
#  1210,
#  335,
#  3835,
#  365,
#  153,
#  126,
#  514,
#  1,
#  2,
#  7,
#  27,
#  1209,
#  136,
#  40,
#  79,
#  12]

# %%
len(train_sequences2[0])
# Out:
# 102

# %%
# Now adding padding
from keras.preprocessing.sequence import pad_sequences 

train_padded2 = pad_sequences(
    train_sequences2, maxlen=max_length, padding='post', truncating='post'
)

# %%
train_padded2[0]
# Out:
# array([  169,   155,     3,   194,    32,  2364,   762, 14982,     9,
#          904,  1095, 12552,    76,    62,   586,   382,   154,   380,
#          816,   547,    19,    59,    42,   390,    20,  1877,  6031,
#         1954,  3800,    19,   431,  2321,  1877,     2,   166,   428,
#          426,  1877,     6,  2374,   431,  6425,   741,    88,  7868,
#          321,   321,  1289,   667,     2], dtype=int32)

# %%
# Creates the test dataset sequences and padding
test_sequences2 = tokenizer.texts_to_sequences(X_test2)
test_padded2 = pad_sequences(
    test_sequences2, maxlen=max_length, padding='post', truncating='post'
)

# %%
print(X_train2.values[0])
print(train_sequences2[0])
# Out:
# looking breakfast place town try stumbled upon mccarthy' it' smaller sized resteraunt think make due space busy saturday afternoon expected got table pretty quickly ordered skillet scrambler pancake significant got eggs benedict skillet good however wouldn' call skillet like scrambled eggs minced meats side scalloped potatoes potatoes melt mouth good eggs cooked excellently toast brought delicious pancake superb size plate nice circumference also thicker pancake great tasted great said eggs benedict alright eggs slightly undercooked hollandaise alright didn' much flavor also would liked ham thicker piece ham instead shaved use overall price reasonable food good service nice throughout visit definitely going back
# [169, 155, 3, 194, 32, 2364, 762, 14982, 9, 904, 1095, 12552, 76, 62, 586, 382, 154, 380, 816, 547, 19, 59, 42, 390, 20, 1877, 6031, 1954, 3800, 19, 431, 2321, 1877, 2, 166, 428, 426, 1877, 6, 2374, 431, 6425, 741, 88, 7868, 321, 321, 1289, 667, 2, 431, 170, 5401, 578, 298, 24, 1954, 1483, 351, 359, 27, 13593, 17, 2765, 1954, 4, 207, 4, 80, 431, 2321, 1462, 431, 712, 1646, 3834, 1462, 44, 49, 110, 17, 15, 354, 1210, 2765, 659, 1210, 335, 3835, 365, 153, 126, 514, 1, 2, 7, 27, 1209, 136, 40, 79, 12]

# %%
# Checks to make sure that you can decode in reverse 
reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

def decode(text):
    return ' '.join([reverse_word_index.get(i, '?') for i in text])

decode(train_sequences2[0])
# Out:
# "looking breakfast place town try stumbled upon mccarthy' it' smaller sized resteraunt think make due space busy saturday afternoon expected got table pretty quickly ordered skillet scrambler pancake significant got eggs benedict skillet good however wouldn' call skillet like scrambled eggs minced meats side scalloped potatoes potatoes melt mouth good eggs cooked excellently toast brought delicious pancake superb size plate nice circumference also thicker pancake great tasted great said eggs benedict alright eggs slightly undercooked hollandaise alright didn' much flavor also would liked ham thicker piece ham instead shaved use overall price reasonable food good service nice throughout visit definitely going back"

# %%
# Checks the shape of the train and the shape of the test
print(f'Shape of train {train_padded2.shape}')
print(f'Shape of test {test_padded2.shape}')
# Out:
# Shape of train (48650, 50)
# Shape of test (16217, 50)

# %% [markdown]
# ### Set up the Network topology
#
# * We could've used One Hot Encoding (OHE) to convert these indices into vectors of 0s an 1s, but this would increase the dimensionality of our features
#
# **Instead...**
# * The Embedding layer - maps each word to a vector of a fixed size with real value elements...
# * In contrast to One Hot Encoding, we can use finite size vector to represent an infinite number of real numbers.
# * We're going to use dimensionality of this embedding layer (32) and the input length will be the max length

# %%
# Sets up network topology 
model2 = Sequential()

model2.add(Embedding(num_words, 32, input_length=max_length))
model2.add(LSTM(64, dropout=0.1))
model2.add(Dense(4, activation='softmax'))

optimizer = Adam(lr=3e-4)

model2.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['acc'])

# %%
# model_l.add(Bidirectional(LSTM(24)))

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 50, 32)            1370880
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 64)                24832
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 1,395,972
# Trainable params: 1,395,972
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model
history2 = model2.fit(
    train_padded2, y_train2, epochs=25, batch_size=256, 
    validation_data=(test_padded2, y_test2)
)
# Out:
# Epoch 1/25
# 191/191 [==============================] - 73s 327ms/step - loss: 1.3601 - acc: 0.3250 - val_loss: 1.1643 - val_acc: 0.4395
# Epoch 2/25
# 191/191 [==============================] - 56s 293ms/step - loss: 1.1096 - acc: 0.4818 - val_loss: 1.0090 - val_acc: 0.5526
# Epoch 3/25
# 191/191 [==============================] - 60s 313ms/step - loss: 0.9156 - acc: 0.6088 - val_loss: 0.9429 - val_acc: 0.5951
# Epoch 4/25
# 191/191 [==============================] - 57s 298ms/step - loss: 0.7928 - acc: 0.6720 - val_loss: 0.9688 - val_acc: 0.5954
# Epoch 5/25
# 191/191 [==============================] - 58s 302ms/step - loss: 0.7065 - acc: 0.7152 - val_loss: 0.9512 - val_acc: 0.6108
# Epoch 6/25
# 191/191 [==============================] - 57s 298ms/step - loss: 0.6516 - acc: 0.7441 - val_loss: 0.9724 - val_acc: 0.6092
# Epoch 7/25
# 191/191 [==============================] - 58s 306ms/step - loss: 0.6075 - acc: 0.7640 - val_loss: 1.0182 - val_acc: 0.6033
# Epoch 8/25
# 191/191 [==============================] - 62s 327ms/step - loss: 0.5731 - acc: 0.7758 - val_loss: 0.9899 - val_acc: 0.6088
# Epoch 9/25
# 191/191 [==============================] - 58s 305ms/step - loss: 0.5468 - acc: 0.7895 - val_loss: 1.0699 - val_acc: 0.6088
# Epoch 10/25
# 191/191 [==============================] - 57s 297ms/step - loss: 0.5112 - acc: 0.8040 - val_loss: 1.0455 - val_acc: 0.6070
# Epoch 11/25
# 191/191 [==============================] - 60s 313ms/step - loss: 0.4903 - acc: 0.8137 - val_loss: 1.0802 - val_acc: 0.6037
# Epoch 12/25
# 191/191 [==============================] - 58s 305ms/step - loss: 0.4783 - acc: 0.8166 - val_loss: 1.1541 - val_acc: 0.6013
# Epoch 13/25
# 191/191 [==============================] - 59s 309ms/step - loss: 0.4514 - acc: 0.8280 - val_loss: 1.2006 - val_acc: 0.5902
# Epoch 14/25
# 191/191 [==============================] - 61s 318ms/step - loss: 0.4629 - acc: 0.8209 - val_loss: 1.2348 - val_acc: 0.5977
# Epoch 15/25
# 191/191 [==============================] - 57s 296ms/step - loss: 0.4220 - acc: 0.8376 - val_loss: 1.2797 - val_acc: 0.5910
# Epoch 16/25
# 191/191 [==============================] - 59s 308ms/step - loss: 0.4166 - acc: 0.8396 - val_loss: 1.2763 - val_acc: 0.5945
# Epoch 17/25
# 191/191 [==============================] - 58s 304ms/step - loss: 0.4011 - acc: 0.8457 - val_loss: 1.2607 - val_acc: 0.5904
# Epoch 18/25
# 191/191 [==============================] - 58s 302ms/step - loss: 0.3971 - acc: 0.8499 - val_loss: 1.2524 - val_acc: 0.5901
# Epoch 19/25
# 191/191 [==============================] - 59s 307ms/step - loss: 0.3850 - acc: 0.8543 - val_loss: 1.3172 - val_acc: 0.5925
# Epoch 20/25
# 191/191 [==============================] - 56s 295ms/step - loss: 0.3719 - acc: 0.8587 - val_loss: 1.3785 - val_acc: 0.5829
# Epoch 21/25
# 191/191 [==============================] - 58s 305ms/step - loss: 0.3825 - acc: 0.8531 - val_loss: 1.4275 - val_acc: 0.5867
# Epoch 22/25
# 191/191 [==============================] - 55s 289ms/step - loss: 0.3633 - acc: 0.8629 - val_loss: 1.3856 - val_acc: 0.5904
# Epoch 23/25
# 191/191 [==============================] - 57s 296ms/step - loss: 0.3522 - acc: 0.8664 - val_loss: 1.3980 - val_acc: 0.5906
# Epoch 24/25
# 191/191 [==============================] - 58s 305ms/step - loss: 0.3376 - acc: 0.8720 - val_loss: 1.4483 - val_acc: 0.5893
# Epoch 25/25
# 191/191 [==============================] - 61s 319ms/step - loss: 0.3332 - acc: 0.8749 - val_loss: 1.4416 - val_acc: 0.5907
